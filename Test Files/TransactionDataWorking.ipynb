# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import re
from jupyter_dash import JupyterDash  # Use JupyterDash instead of dash.Dash
import dash
from dash import html
import dash_cytoscape as cyto

# %%
# Function to clean column names
def clean_column_name(name):
    # Convert to lowercase
    name = name.lower()
    # Replace spaces with underscores
    name = name.replace(' ', '_')
    # Remove special characters (except underscores)
    name = re.sub(r'[^\w\s]', '', name)
    return name

# Apply the function to each column name
#df.columns = [clean_column_name(col) for col in df.columns]

# %%
# Read the CSV file
file_path = 'D:\\test\\excel2.xlsx'  # Replace with your file path
df = pd.read_excel(file_path, dtype= str)

df.columns = [clean_column_name(col) for col in df.columns]
# Create a list to hold new rows
new_rows = []
# List of columns where you want to append '@'
columns_to_append = ['acknowledgement_no','transaction_id','to_account_no', 'from_account_no','utr_number']

# Prepend '@' to every value in the specified columns
for column in columns_to_append:
    if column in df.columns:
        df[column] = df[column].apply(lambda x: '`' + str(x) if pd.notnull(x) else x)

# Function to process columns and split rows
def process_column(df, column_name):
    new_rows = []
    for index, row in df.iterrows():
         # Ensure the column values are strings
        value = str(row[column_name])
        # Split the values in the column based on spaces and strip any extra spaces
        values = [val.strip() for val in row[column_name].split() if val.strip()]
        
        # If there's more than one value, create a new row for each value
        if len(values) > 1:
            for value in values:
                new_row = row.copy()  # Copy the original row
                new_row[column_name] = value  # Update with the trimmed text
                new_rows.append(new_row)
        else:
            # Keep the original row if there's only one value (no split needed)
            new_rows.append(row)
    return pd.DataFrame(new_rows)

# List of columns to process
columns_to_process = ['transaction_id', 'from_account_no'] # add to account no if there are dual records in it

# Ensure columns are in string format
for col in columns_to_process:
    if col in df.columns:
        df[col] = df[col].astype(str)
        
# Process each column and merge results
processed_dfs = [process_column(df, col) for col in columns_to_process]
# Merge all processed DataFrames
final_df = pd.concat(processed_dfs, ignore_index=True)

# Display the updated DataFrame to verify
print(final_df.head())

# Save the modified DataFrame to a new CSV file if needed
final_df.to_csv('D:\\test\\excel2_Cleaned.csv', index=False)
df = final_df
# Out:
#   s_no acknowledgement_no           transaction_id layer      to_account_no  \
# 0    1    `30209240022092  `PUNBR52024090612314232     2  `8830210000008880
# 1    2    `30209240022092  `PUNBR52024090612314232     2  `8830210000008880
# 2    3    `30209240022092  `PUNBR52024090612314232     2  `8830210000008880
# 3    4    `30209240022092  `PUNBR52024090612314232     2  `8830210000008880
# 4    5    `30209240022092  `PUNBR52024090612314232     2  `8830210000008880
#
#   action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 0                                  Money Transfer to
# 1                                  Money Transfer to
# 2                                  Money Transfer to
# 3                                  Money Transfer to
# 4                                  Money Transfer to
#
#   bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 0                         Federal Bank   `24610100000643  FDRL0001010
# 1                         Canara Bank      `110196345628  CNRB0004785
# 2                         Canara Bank      `110189607716  CNRB0004785
# 3                    South Indian Bank  `179053000017033  SIBL0000848
# 4                         Bandhan Bank   `20200057515505  BDBL0001815
#
#   cheque_no  ... reference_no                                     remarks  \
# 0         0  ...          NaN               RTGS 0830OI4005165954 BHUPESH
# 1         0  ...          NaN             RTGS 0830OI4005165914 JUNJA RAM
# 2         0  ...          NaN              RTGS 0830OI4005165956 AKBARALI
# 3         0  ...          NaN  RTGS 0830OI4005165915 SHAIKH MOHAMMEDSAJID
# 4         0  ...          NaN                RTGS 0830OI4005165951 KISHOR
#
#         date_of_action                     action_taken_by_bank  \
# 0  2024-09-22 17:46:59  DBS Bank (Including Lakshmi Vilas Bank)
# 1  2024-09-22 17:46:59  DBS Bank (Including Lakshmi Vilas Bank)
# 2  2024-09-22 17:46:59  DBS Bank (Including Lakshmi Vilas Bank)
# 3  2024-09-22 17:46:59  DBS Bank (Including Lakshmi Vilas Bank)
# 4  2024-09-22 17:46:59  DBS Bank (Including Lakshmi Vilas Bank)
#
#   action_taken_name    action_taken_by_email branch_location  \
# 0  Akanksha Bhagade  akankshabhagade@dbs.com             NaN
# 1  Akanksha Bhagade  akankshabhagade@dbs.com             NaN
# 2  Akanksha Bhagade  akankshabhagade@dbs.com             NaN
# 3  Akanksha Bhagade  akankshabhagade@dbs.com             NaN
# 4  Akanksha Bhagade  akankshabhagade@dbs.com             NaN
#
#    branch_manager_name__contact_details unnamed_25 unnamed_26
# 0                                   NaN        NaN        NaN
# 1                                   NaN        NaN        NaN
# 2                                   NaN        NaN        NaN
# 3                                   NaN        NaN        NaN
# 4                                   NaN        NaN        NaN
#
# [5 rows x 27 columns]

# %%
#df = df.drop(['unique_id'],axis=1)
df = df.drop(['s_no'],axis=1)
# Remove text within square brackets
df['to_account_no'] = df['to_account_no'].str.replace(r'\s*\[.*?\]', '', regex=True)

# %%
# Define the columns to clean
columns_to_clean = [
    'acknowledgement_no', 'transaction_id', 'layer',
    'from_account_no', 'utr_number', 'amount','to_account_no'
]

# Function to clean data in a column
def clean_column_data(series):
    # Remove special characters and trim spaces
    series = series.apply(lambda x: re.sub(r'[^\w\s]', '', str(x)).strip() if pd.notna(x) else x)
    return series

# Apply the cleaning function to each specified column
for col in columns_to_clean:
    if col in df.columns:
        df[col] = clean_column_data(df[col])

# Display the cleaned data to verify
print(df[columns_to_clean].head())
# Out:
#   acknowledgement_no          transaction_id layer  from_account_no  \
# 0     30209240022092  PUNBR52024090612314232     2   24610100000643
# 1     30209240022092  PUNBR52024090612314232     2     110196345628
# 2     30209240022092  PUNBR52024090612314232     2     110189607716
# 3     30209240022092  PUNBR52024090612314232     2  179053000017033
# 4     30209240022092  PUNBR52024090612314232     2   20200057515505
#
#                utr_number  amount     to_account_no
# 0  DBSSR52024090605165954  270000  8830210000008880
# 1  DBSSR52024090605165914  200000  8830210000008880
# 2             CNRB0004785  399999  8830210000008880
# 3  DBSSR52024090605165915  371900  8830210000008880
# 4  DBSSR52024090605165951  290178  8830210000008880

# %%
df['unique_id'] = pd.Series(range(1, len(df) + 1))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 27 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   acknowledgement_no                                   312 non-null    object
#  1   transaction_id                                       312 non-null    object
#  2   layer                                                312 non-null    object
#  3   to_account_no                                        312 non-null    object
#  4   action_taken_by_bank_wallet_pgpa_merchant_insurance  312 non-null    object
#  5   bank_wallet_pgpa_merchant__insurance                 312 non-null    object
#  6   from_account_no                                      312 non-null    object
#  7   ifsc_code                                            195 non-null    object
#  8   cheque_no                                            312 non-null    object
#  9   mid                                                  9 non-null      object
#  10  tid                                                  9 non-null      object
#  11  approval_code                                        9 non-null      object
#  12  merchant_name                                        9 non-null      object
#  13  transaction_date                                     312 non-null    object
#  14  utr_number                                           218 non-null    object
#  15  amount                                               312 non-null    object
#  16  reference_no                                         0 non-null      float64
#  17  remarks                                              236 non-null    object
#  18  date_of_action                                       312 non-null    object
#  19  action_taken_by_bank                                 312 non-null    object
#  20  action_taken_name                                    312 non-null    object
#  21  action_taken_by_email                                312 non-null    object
#  22  branch_location                                      42 non-null     object
#  23  branch_manager_name__contact_details                 16 non-null     object
#  24  unnamed_25                                           6 non-null      object
#  25  unnamed_26                                           2 non-null      object
#  26  unique_id                                            312 non-null    int64
# dtypes: float64(1), int64(1), object(25)
# memory usage: 65.9+ KB

# %%
df['layer'] = pd.to_numeric(df['layer'], errors='coerce')
print(df['layer'].unique())
df.info()
# Out:
# [2 3 1 4 5 6 7]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 312 entries, 0 to 311
# Data columns (total 27 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   acknowledgement_no                                   312 non-null    object
#  1   transaction_id                                       312 non-null    object
#  2   layer                                                312 non-null    int64
#  3   to_account_no                                        312 non-null    object
#  4   action_taken_by_bank_wallet_pgpa_merchant_insurance  312 non-null    object
#  5   bank_wallet_pgpa_merchant__insurance                 312 non-null    object
#  6   from_account_no                                      312 non-null    object
#  7   ifsc_code                                            195 non-null    object
#  8   cheque_no                                            312 non-null    object
#  9   mid                                                  9 non-null      object
#  10  tid                                                  9 non-null      object
#  11  approval_code                                        9 non-null      object
#  12  merchant_name                                        9 non-null      object
#  13  transaction_date                                     312 non-null    object
#  14  utr_number                                           218 non-null    object
#  15  amount                                               312 non-null    object
#  16  reference_no                                         0 non-null      float64
#  17  remarks                                              236 non-null    object
#  18  date_of_action                                       312 non-null    object
#  19  action_taken_by_bank                                 312 non-null    object
#  20  action_taken_name                                    312 non-null    object
#  21  action_taken_by_email                                312 non-null    object
#  22  branch_location                                      42 non-null     object
#  23  branch_manager_name__contact_details                 16 non-null     object
#  24  unnamed_25                                           6 non-null      object
#  25  unnamed_26                                           2 non-null      object
#  26  unique_id                                            312 non-null    int64
# dtypes: float64(1), int64(2), object(24)
# memory usage: 65.9+ KB

# %%
layers = df.groupby('layer')
layer1 = layers.get_group(1)
layer1
# Out:
#     acknowledgement_no          transaction_id  layer     to_account_no  \
# 21      30209240022092  SBINR52024090646591003      1  8830210000008880
# 34      30209240022092  PUNBR52024090612314232      1    10832030036580
# 38      30209240022092  PUNBR52024090612314232      1  8830210000008880
# 39      30209240022092  SBINR52024090646591003      1       10047593897
# 40      30209240022092                  965562      1       10047593897
# 41      30209240022092                  965563      1       10047593897
# 42      30209240022092                  965562      1       43017388358
# 43      30209240022092                  965563      1       43280321955
# 44      30209240022092             10047593897      1       43017388358
# 45      30209240022092             10047593897      1       43280321955
# 52      30209240022092  SBINR52024090646591003      1  8830210000008880
# 177     30209240022092  SBINR52024090646591003      1  8830210000008880
# 190     30209240022092  PUNBR52024090612314232      1    10832030036580
# 194     30209240022092  PUNBR52024090612314232      1  8830210000008880
# 195     30209240022092  SBINR52024090646591003      1       10047593897
# 196     30209240022092                  965562      1       10047593897
# 197     30209240022092                  965563      1       10047593897
# 198     30209240022092                  965562      1       43017388358
# 199     30209240022092                  965563      1       43280321955
# 200     30209240022092             10047593897      1       43017388358
# 201     30209240022092             10047593897      1       43280321955
# 208     30209240022092  SBINR52024090646591003      1  8830210000008880
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 21                             Transaction put on hold
# 34                                   Money Transfer to
# 38                                               Other
# 39                                   Money Transfer to
# 40                                   Money Transfer to
# 41                                   Money Transfer to
# 42                                               Other
# 43                                               Other
# 44                                               Other
# 45                                               Other
# 52                                               Other
# 177                            Transaction put on hold
# 190                                  Money Transfer to
# 194                                              Other
# 195                                  Money Transfer to
# 196                                  Money Transfer to
# 197                                  Money Transfer to
# 198                                              Other
# 199                                              Other
# 200                                              Other
# 201                                              Other
# 208                                              Other
#
#     bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 21                             DBS Bank   1146110010053650          NaN
# 34                             DBS Bank   8830210000008880  DBSS0IN0830
# 38                             DBS Bank                nan          NaN
# 39                             DBS Bank   8830210000008880  DBSS0IN0830
# 40                   State Bank of India       43017388358  SBIN0001464
# 41                   State Bank of India       43280321955  SBIN0011519
# 42                   State Bank of India               nan          NaN
# 43                   State Bank of India               nan          NaN
# 44                   State Bank of India               nan          NaN
# 45                   State Bank of India               nan          NaN
# 52                             DBS Bank                nan          NaN
# 177                            DBS Bank   1146110010053650          NaN
# 190                            DBS Bank   8830210000008880  DBSS0IN0830
# 194                            DBS Bank                nan          NaN
# 195                            DBS Bank   8830210000008880  DBSS0IN0830
# 196                  State Bank of India       43017388358  SBIN0001464
# 197                  State Bank of India       43280321955  SBIN0011519
# 198                  State Bank of India               nan          NaN
# 199                  State Bank of India               nan          NaN
# 200                  State Bank of India               nan          NaN
# 201                  State Bank of India               nan          NaN
# 208                            DBS Bank                nan          NaN
#
#     cheque_no  mid  ...                                            remarks  \
# 21          0  NaN  ...                           Transaction put on hold.
# 34          0  NaN  ...  NRTGS/PUNBR52024090612314232/CRAVY MEALES ENTE...
# 38          0  NaN  ...                              Duplicate transaction
# 39          0  NaN  ...                      Transaction amount 2799952.80
# 40          0  NaN  ...                                                NaN
# 41          0  NaN  ...                                                NaN
# 42          0  NaN  ...  Account does not have sufficient balance. However
# 43          0  NaN  ...  Account does not have sufficient balance. However
# 44          0  NaN  ...    Repeated transaction. Action already initiated.
# 45          0  NaN  ...    Repeated transaction. Action already initiated.
# 52          0  NaN  ...                                  Already actioned.
# 177         0  NaN  ...                           Transaction put on hold.
# 190         0  NaN  ...  NRTGS/PUNBR52024090612314232/CRAVY MEALES ENTE...
# 194         0  NaN  ...                              Duplicate transaction
# 195         0  NaN  ...                      Transaction amount 2799952.80
# 196         0  NaN  ...                                                NaN
# 197         0  NaN  ...                                                NaN
# 198         0  NaN  ...  Account does not have sufficient balance. However
# 199         0  NaN  ...  Account does not have sufficient balance. However
# 200         0  NaN  ...    Repeated transaction. Action already initiated.
# 201         0  NaN  ...    Repeated transaction. Action already initiated.
# 208         0  NaN  ...                                  Already actioned.
#
#                                     date_of_action  \
# 21                             2024-09-22 17:59:28
# 34                             2024-09-22 18:06:13
# 38                             2024-09-22 18:10:40
# 39                             2024-09-22 18:13:57
# 40                             2024-09-22 18:18:25
# 41                             2024-09-22 18:19:12
# 42    Hold Kept for the disputed amount Rs.1100000
# 43    Hold Kept for the disputed amount Rs.1200000
# 44                             2024-09-22 18:20:28
# 45                             2024-09-22 18:20:39
# 52                             2024-09-22 18:30:40
# 177                            2024-09-22 17:59:28
# 190                            2024-09-22 18:06:13
# 194                            2024-09-22 18:10:40
# 195                            2024-09-22 18:13:57
# 196                            2024-09-22 18:18:25
# 197                            2024-09-22 18:19:12
# 198   Hold Kept for the disputed amount Rs.1100000
# 199   Hold Kept for the disputed amount Rs.1200000
# 200                            2024-09-22 18:20:28
# 201                            2024-09-22 18:20:39
# 208                            2024-09-22 18:30:40
#
#                                   action_taken_by_bank    action_taken_name  \
# 21             DBS Bank (Including Lakshmi Vilas Bank)     Akanksha Bhagade
# 34   Punjab National Bank (including Oriental Bank ...          Rahul Singh
# 38             DBS Bank (Including Lakshmi Vilas Bank)          Ajeet Kumar
# 39                                 State Bank of India      S V Vinod Kumar
# 40                                 State Bank of India      S V Vinod Kumar
# 41                                 State Bank of India      S V Vinod Kumar
# 42                                 2024-09-22 18:19:43  State Bank of India
# 43                                 2024-09-22 18:19:56  State Bank of India
# 44                                 State Bank of India      S V Vinod Kumar
# 45                                 State Bank of India      S V Vinod Kumar
# 52             DBS Bank (Including Lakshmi Vilas Bank)     Akanksha Bhagade
# 177            DBS Bank (Including Lakshmi Vilas Bank)     Akanksha Bhagade
# 190  Punjab National Bank (including Oriental Bank ...          Rahul Singh
# 194            DBS Bank (Including Lakshmi Vilas Bank)          Ajeet Kumar
# 195                                State Bank of India      S V Vinod Kumar
# 196                                State Bank of India      S V Vinod Kumar
# 197                                State Bank of India      S V Vinod Kumar
# 198                                2024-09-22 18:19:43  State Bank of India
# 199                                2024-09-22 18:19:56  State Bank of India
# 200                                State Bank of India      S V Vinod Kumar
# 201                                State Bank of India      S V Vinod Kumar
# 208            DBS Bank (Including Lakshmi Vilas Bank)     Akanksha Bhagade
#
#         action_taken_by_email           branch_location  \
# 21    akankshabhagade@dbs.com                       NaN
# 34       nccrpc.i4c@pnb.co.in                       NaN
# 38         ajeetkumar@dbs.com                       NaN
# 39   agmsrvl.lhoand@sbi.co.in                       NaN
# 40   agmsrvl.lhoand@sbi.co.in                       NaN
# 41   agmsrvl.lhoand@sbi.co.in                       NaN
# 42            S V Vinod Kumar  agmsrvl.lhoand@sbi.co.in
# 43            S V Vinod Kumar  agmsrvl.lhoand@sbi.co.in
# 44   agmsrvl.lhoand@sbi.co.in                       NaN
# 45   agmsrvl.lhoand@sbi.co.in                       NaN
# 52    akankshabhagade@dbs.com                       NaN
# 177   akankshabhagade@dbs.com                       NaN
# 190      nccrpc.i4c@pnb.co.in                       NaN
# 194        ajeetkumar@dbs.com                       NaN
# 195  agmsrvl.lhoand@sbi.co.in                       NaN
# 196  agmsrvl.lhoand@sbi.co.in                       NaN
# 197  agmsrvl.lhoand@sbi.co.in                       NaN
# 198           S V Vinod Kumar  agmsrvl.lhoand@sbi.co.in
# 199           S V Vinod Kumar  agmsrvl.lhoand@sbi.co.in
# 200  agmsrvl.lhoand@sbi.co.in                       NaN
# 201  agmsrvl.lhoand@sbi.co.in                       NaN
# 208   akankshabhagade@dbs.com                       NaN
#
#      branch_manager_name__contact_details unnamed_25 unnamed_26 unique_id
# 21                                    NaN        NaN        NaN        22
# 34                                    NaN        NaN        NaN        35
# 38                                    NaN        NaN        NaN        39
# 39                                    NaN        NaN        NaN        40
# 40                                    NaN        NaN        NaN        41
# 41                                    NaN        NaN        NaN        42
# 42                                    NaN        NaN        NaN        43
# 43                                    NaN        NaN        NaN        44
# 44                                    NaN        NaN        NaN        45
# 45                                    NaN        NaN        NaN        46
# 52                                    NaN        NaN        NaN        53
# 177                                   NaN        NaN        NaN       178
# 190                                   NaN        NaN        NaN       191
# 194                                   NaN        NaN        NaN       195
# 195                                   NaN        NaN        NaN       196
# 196                                   NaN        NaN        NaN       197
# 197                                   NaN        NaN        NaN       198
# 198                                   NaN        NaN        NaN       199
# 199                                   NaN        NaN        NaN       200
# 200                                   NaN        NaN        NaN       201
# 201                                   NaN        NaN        NaN       202
# 208                                   NaN        NaN        NaN       209
#
# [22 rows x 27 columns]

# %%
# Assuming df contains your data
layers = df.groupby('layer')
for layer_num, layer_data in layers:
    # Get distinct account numbers
    print(layer_data)
    distinct_accounts = layer_data['from_account_no'].unique()
    print(distinct_accounts)
# Out:
#     acknowledgement_no          transaction_id  layer     to_account_no  \
# 21      30209240022092  SBINR52024090646591003      1  8830210000008880
# 34      30209240022092  PUNBR52024090612314232      1    10832030036580
# 38      30209240022092  PUNBR52024090612314232      1  8830210000008880
# 39      30209240022092  SBINR52024090646591003      1       10047593897
# 40      30209240022092                  965562      1       10047593897
# 41      30209240022092                  965563      1       10047593897
# 42      30209240022092                  965562      1       43017388358
# 43      30209240022092                  965563      1       43280321955
# 44      30209240022092             10047593897      1       43017388358
# 45      30209240022092             10047593897      1       43280321955
# 52      30209240022092  SBINR52024090646591003      1  8830210000008880
# 177     30209240022092  SBINR52024090646591003      1  8830210000008880
# 190     30209240022092  PUNBR52024090612314232      1    10832030036580
# 194     30209240022092  PUNBR52024090612314232      1  8830210000008880
# 195     30209240022092  SBINR52024090646591003      1       10047593897
# 196     30209240022092                  965562      1       10047593897
# 197     30209240022092                  965563      1       10047593897
# 198     30209240022092                  965562      1       43017388358
# 199     30209240022092                  965563      1       43280321955
# 200     30209240022092             10047593897      1       43017388358
# 201     30209240022092             10047593897      1       43280321955
# 208     30209240022092  SBINR52024090646591003      1  8830210000008880
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 21                             Transaction put on hold
# 34                                   Money Transfer to
# 38                                               Other
# 39                                   Money Transfer to
# 40                                   Money Transfer to
# 41                                   Money Transfer to
# 42                                               Other
# 43                                               Other
# 44                                               Other
# 45                                               Other
# 52                                               Other
# 177                            Transaction put on hold
# 190                                  Money Transfer to
# 194                                              Other
# 195                                  Money Transfer to
# 196                                  Money Transfer to
# 197                                  Money Transfer to
# 198                                              Other
# 199                                              Other
# 200                                              Other
# 201                                              Other
# 208                                              Other
#
#     bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 21                             DBS Bank   1146110010053650          NaN
# 34                             DBS Bank   8830210000008880  DBSS0IN0830
# 38                             DBS Bank                nan          NaN
# 39                             DBS Bank   8830210000008880  DBSS0IN0830
# 40                   State Bank of India       43017388358  SBIN0001464
# 41                   State Bank of India       43280321955  SBIN0011519
# 42                   State Bank of India               nan          NaN
# 43                   State Bank of India               nan          NaN
# 44                   State Bank of India               nan          NaN
# 45                   State Bank of India               nan          NaN
# 52                             DBS Bank                nan          NaN
# 177                            DBS Bank   1146110010053650          NaN
# 190                            DBS Bank   8830210000008880  DBSS0IN0830
# 194                            DBS Bank                nan          NaN
# 195                            DBS Bank   8830210000008880  DBSS0IN0830
# 196                  State Bank of India       43017388358  SBIN0001464
# 197                  State Bank of India       43280321955  SBIN0011519
# 198                  State Bank of India               nan          NaN
# 199                  State Bank of India               nan          NaN
# 200                  State Bank of India               nan          NaN
# 201                  State Bank of India               nan          NaN
# 208                            DBS Bank                nan          NaN
#
#     cheque_no  mid  ...                                            remarks  \
# 21          0  NaN  ...                           Transaction put on hold.
# 34          0  NaN  ...  NRTGS/PUNBR52024090612314232/CRAVY MEALES ENTE...
# 38          0  NaN  ...                              Duplicate transaction
# 39          0  NaN  ...                      Transaction amount 2799952.80
# 40          0  NaN  ...                                                NaN
# 41          0  NaN  ...                                                NaN
# 42          0  NaN  ...  Account does not have sufficient balance. However
# 43          0  NaN  ...  Account does not have sufficient balance. However
# 44          0  NaN  ...    Repeated transaction. Action already initiated.
# 45          0  NaN  ...    Repeated transaction. Action already initiated.
# 52          0  NaN  ...                                  Already actioned.
# 177         0  NaN  ...                           Transaction put on hold.
# 190         0  NaN  ...  NRTGS/PUNBR52024090612314232/CRAVY MEALES ENTE...
# 194         0  NaN  ...                              Duplicate transaction
# 195         0  NaN  ...                      Transaction amount 2799952.80
# 196         0  NaN  ...                                                NaN
# 197         0  NaN  ...                                                NaN
# 198         0  NaN  ...  Account does not have sufficient balance. However
# 199         0  NaN  ...  Account does not have sufficient balance. However
# 200         0  NaN  ...    Repeated transaction. Action already initiated.
# 201         0  NaN  ...    Repeated transaction. Action already initiated.
# 208         0  NaN  ...                                  Already actioned.
#
#                                     date_of_action  \
# 21                             2024-09-22 17:59:28
# 34                             2024-09-22 18:06:13
# 38                             2024-09-22 18:10:40
# 39                             2024-09-22 18:13:57
# 40                             2024-09-22 18:18:25
# 41                             2024-09-22 18:19:12
# 42    Hold Kept for the disputed amount Rs.1100000
# 43    Hold Kept for the disputed amount Rs.1200000
# 44                             2024-09-22 18:20:28
# 45                             2024-09-22 18:20:39
# 52                             2024-09-22 18:30:40
# 177                            2024-09-22 17:59:28
# 190                            2024-09-22 18:06:13
# 194                            2024-09-22 18:10:40
# 195                            2024-09-22 18:13:57
# 196                            2024-09-22 18:18:25
# 197                            2024-09-22 18:19:12
# 198   Hold Kept for the disputed amount Rs.1100000
# 199   Hold Kept for the disputed amount Rs.1200000
# 200                            2024-09-22 18:20:28
# 201                            2024-09-22 18:20:39
# 208                            2024-09-22 18:30:40
#
#                                   action_taken_by_bank    action_taken_name  \
# 21             DBS Bank (Including Lakshmi Vilas Bank)     Akanksha Bhagade
# 34   Punjab National Bank (including Oriental Bank ...          Rahul Singh
# 38             DBS Bank (Including Lakshmi Vilas Bank)          Ajeet Kumar
# 39                                 State Bank of India      S V Vinod Kumar
# 40                                 State Bank of India      S V Vinod Kumar
# 41                                 State Bank of India      S V Vinod Kumar
# 42                                 2024-09-22 18:19:43  State Bank of India
# 43                                 2024-09-22 18:19:56  State Bank of India
# 44                                 State Bank of India      S V Vinod Kumar
# 45                                 State Bank of India      S V Vinod Kumar
# 52             DBS Bank (Including Lakshmi Vilas Bank)     Akanksha Bhagade
# 177            DBS Bank (Including Lakshmi Vilas Bank)     Akanksha Bhagade
# 190  Punjab National Bank (including Oriental Bank ...          Rahul Singh
# 194            DBS Bank (Including Lakshmi Vilas Bank)          Ajeet Kumar
# 195                                State Bank of India      S V Vinod Kumar
# 196                                State Bank of India      S V Vinod Kumar
# 197                                State Bank of India      S V Vinod Kumar
# 198                                2024-09-22 18:19:43  State Bank of India
# 199                                2024-09-22 18:19:56  State Bank of India
# 200                                State Bank of India      S V Vinod Kumar
# 201                                State Bank of India      S V Vinod Kumar
# 208            DBS Bank (Including Lakshmi Vilas Bank)     Akanksha Bhagade
#
#         action_taken_by_email           branch_location  \
# 21    akankshabhagade@dbs.com                       NaN
# 34       nccrpc.i4c@pnb.co.in                       NaN
# 38         ajeetkumar@dbs.com                       NaN
# 39   agmsrvl.lhoand@sbi.co.in                       NaN
# 40   agmsrvl.lhoand@sbi.co.in                       NaN
# 41   agmsrvl.lhoand@sbi.co.in                       NaN
# 42            S V Vinod Kumar  agmsrvl.lhoand@sbi.co.in
# 43            S V Vinod Kumar  agmsrvl.lhoand@sbi.co.in
# 44   agmsrvl.lhoand@sbi.co.in                       NaN
# 45   agmsrvl.lhoand@sbi.co.in                       NaN
# 52    akankshabhagade@dbs.com                       NaN
# 177   akankshabhagade@dbs.com                       NaN
# 190      nccrpc.i4c@pnb.co.in                       NaN
# 194        ajeetkumar@dbs.com                       NaN
# 195  agmsrvl.lhoand@sbi.co.in                       NaN
# 196  agmsrvl.lhoand@sbi.co.in                       NaN
# 197  agmsrvl.lhoand@sbi.co.in                       NaN
# 198           S V Vinod Kumar  agmsrvl.lhoand@sbi.co.in
# 199           S V Vinod Kumar  agmsrvl.lhoand@sbi.co.in
# 200  agmsrvl.lhoand@sbi.co.in                       NaN
# 201  agmsrvl.lhoand@sbi.co.in                       NaN
# 208   akankshabhagade@dbs.com                       NaN
#
#      branch_manager_name__contact_details unnamed_25 unnamed_26 unique_id
# 21                                    NaN        NaN        NaN        22
# 34                                    NaN        NaN        NaN        35
# 38                                    NaN        NaN        NaN        39
# 39                                    NaN        NaN        NaN        40
# 40                                    NaN        NaN        NaN        41
# 41                                    NaN        NaN        NaN        42
# 42                                    NaN        NaN        NaN        43
# 43                                    NaN        NaN        NaN        44
# 44                                    NaN        NaN        NaN        45
# 45                                    NaN        NaN        NaN        46
# 52                                    NaN        NaN        NaN        53
# 177                                   NaN        NaN        NaN       178
# 190                                   NaN        NaN        NaN       191
# 194                                   NaN        NaN        NaN       195
# 195                                   NaN        NaN        NaN       196
# 196                                   NaN        NaN        NaN       197
# 197                                   NaN        NaN        NaN       198
# 198                                   NaN        NaN        NaN       199
# 199                                   NaN        NaN        NaN       200
# 200                                   NaN        NaN        NaN       201
# 201                                   NaN        NaN        NaN       202
# 208                                   NaN        NaN        NaN       209
#
# [22 rows x 27 columns]
# ['1146110010053650' '8830210000008880' 'nan' '43017388358' '43280321955']
#     acknowledgement_no          transaction_id  layer     to_account_no  \
# 0       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 1       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 2       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 3       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 4       30209240022092  PUNBR52024090612314232      2  8830210000008880
# ..                 ...                     ...    ...               ...
# 292     30209240022092  DBSSR52024090605165952      2    50100741696880
# 293     30209240022092  DBSSR52024090605165952      2    50100741696880
# 304     30209240022092  PUNBR52024090612314232      2  8830210000008880
# 305     30209240022092  DBSSR52024090605165952      2    50100741696880
# 306     30209240022092  PUNBR52024090612314232      2  8830210000008880
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 0                                    Money Transfer to
# 1                                    Money Transfer to
# 2                                    Money Transfer to
# 3                                    Money Transfer to
# 4                                    Money Transfer to
# ..                                                 ...
# 292                             Withdrawal through POS
# 293                             Withdrawal through POS
# 304                                  Money Transfer to
# 305                             Withdrawal through POS
# 306                                  Money Transfer to
#
#     bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 0                           Federal Bank    24610100000643  FDRL0001010
# 1                           Canara Bank       110196345628  CNRB0004785
# 2                           Canara Bank       110189607716  CNRB0004785
# 3                      South Indian Bank   179053000017033  SIBL0000848
# 4                           Bandhan Bank    20200057515505  BDBL0001815
# ..                                   ...               ...          ...
# 292                            HDFC Bank               nan          NaN
# 293                            HDFC Bank               nan          NaN
# 304                            HDFC Bank    50100741696880  HDFC0000365
# 305                            HDFC Bank               nan          NaN
# 306   Utkarsh Small Finance Bank Limited  1564017023043730  UTKS0001564
#
#     cheque_no              mid  ...  \
# 0           0              NaN  ...
# 1           0              NaN  ...
# 2           0              NaN  ...
# 3           0              NaN  ...
# 4           0              NaN  ...
# ..        ...              ...  ...
# 292         0  114400000006186  ...
# 293         0     200601405418  ...
# 304         0              NaN  ...
# 305         0     200601405418  ...
# 306         0              NaN  ...
#
#                                                remarks       date_of_action  \
# 0                        RTGS 0830OI4005165954 BHUPESH  2024-09-22 17:46:59
# 1                      RTGS 0830OI4005165914 JUNJA RAM  2024-09-22 17:46:59
# 2                       RTGS 0830OI4005165956 AKBARALI  2024-09-22 17:46:59
# 3           RTGS 0830OI4005165915 SHAIKH MOHAMMEDSAJID  2024-09-22 17:46:59
# 4                         RTGS 0830OI4005165951 KISHOR  2024-09-22 17:46:59
# ..                                                 ...                  ...
# 292                                       425011002844  2024-09-23 14:58:13
# 293                                425012256134 DA 181  2024-09-23 14:59:54
# 304  RTGS 0830OI4005165952 MOHD MUZAFFERAMEENUDDIN(...  2024-09-26 23:33:36
# 305                                   0830OI4005165952  2024-09-27 00:07:13
# 306               RTGS 0830OI4005165962 VIKASH BISHNOI  2024-09-27 12:18:17
#
#                         action_taken_by_bank action_taken_name  \
# 0    DBS Bank (Including Lakshmi Vilas Bank)  Akanksha Bhagade
# 1    DBS Bank (Including Lakshmi Vilas Bank)  Akanksha Bhagade
# 2    DBS Bank (Including Lakshmi Vilas Bank)  Akanksha Bhagade
# 3    DBS Bank (Including Lakshmi Vilas Bank)  Akanksha Bhagade
# 4    DBS Bank (Including Lakshmi Vilas Bank)  Akanksha Bhagade
# ..                                       ...               ...
# 292                                HDFC Bank    Yukesh Kumar R
# 293                                HDFC Bank    Yukesh Kumar R
# 304  DBS Bank (Including Lakshmi Vilas Bank)    Tanmay Kumbhar
# 305                                HDFC Bank   Sikander Sharma
# 306  DBS Bank (Including Lakshmi Vilas Bank)  Akanksha Bhagade
#
#             action_taken_by_email branch_location  \
# 0         akankshabhagade@dbs.com             NaN
# 1         akankshabhagade@dbs.com             NaN
# 2         akankshabhagade@dbs.com             NaN
# 3         akankshabhagade@dbs.com             NaN
# 4         akankshabhagade@dbs.com             NaN
# ..                            ...             ...
# 292   yukeshkumar.r1@hdfcbank.com             NaN
# 293   yukeshkumar.r1@hdfcbank.com             NaN
# 304         tanmaykumbhar@dbs.com             NaN
# 305  sikandra.sharma@hdfcbank.com             NaN
# 306       akankshabhagade@dbs.com             NaN
#
#      branch_manager_name__contact_details unnamed_25 unnamed_26 unique_id
# 0                                     NaN        NaN        NaN         1
# 1                                     NaN        NaN        NaN         2
# 2                                     NaN        NaN        NaN         3
# 3                                     NaN        NaN        NaN         4
# 4                                     NaN        NaN        NaN         5
# ..                                    ...        ...        ...       ...
# 292                                   NaN        NaN        NaN       293
# 293                                   NaN        NaN        NaN       294
# 304                                   NaN        NaN        NaN       305
# 305                                   NaN        NaN        NaN       306
# 306                                   NaN        NaN        NaN       307
#
# [102 rows x 27 columns]
# ['24610100000643' '110196345628' '110189607716' '179053000017033'
#  '20200057515505' '20200059779220' '2401216960825130' '1607104000080370'
#  '21360100147753' '2401227259431240' '20200059117762' '60496115000'
#  '60501402002' '1146110010053650' '20200050694941' '18670100063718'
#  '24610100005204' '79801513015' '110170638899' '20200060776541'
#  '20200060503423' '1564019694617840' '110134809783' '20200060530420'
#  '1001014000220' '22751400002853' '20200058727202' '924010041487963' 'nan'
#  '922010019482631' 'WPGTID01' '44963344' '50100277170880'
#  '131451400002071' '50100741696880' '1564017023043730']
#     acknowledgement_no          transaction_id  layer       to_account_no  \
# 14      30209240022092  DBSSR52024090605165916      3    2401227259431240
# 15      30209240022092  DBSSR52024090605165958      3    2401216960825130
# 16      30209240022092  DBSSR52024090605165955      3         60496115000
# 17      30209240022092  DBSSR52024090605165953      3         60501402002
# 18      30209240022092  DBSSR52024090605165916      3    2401227259431240
# ..                 ...                     ...    ...                 ...
# 303     30209240022092  SBINR12024091047262737      3    1564019694617840
# 307     30209240022092  DBSSR52024090605166760      3    1146110010053650
# 308     30209240022092  DBSSR52024090605166760      3    1146110010053650
# 309     30209240022092  UJVNN52024090646162643      3    KSCS034101003544
# 310     30209240022092  UJVNN52024090646162610      3  MRCB10002001005429
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 14                                   Money Transfer to
# 15                                   Money Transfer to
# 16                                   Money Transfer to
# 17                                   Money Transfer to
# 18                                   Money Transfer to
# ..                                                 ...
# 303                                  Money Transfer to
# 307                                  Money Transfer to
# 308                                  Money Transfer to
# 309                                              Other
# 310                                              Other
#
#     bank_wallet_pgpa_merchant__insurance     from_account_no    ifsc_code  \
# 14                          Canara Bank         110171398496  CNRB0000001
# 15                         Bank of India     746310110004930  BKID0000001
# 16                          Federal Bank      19680100099710  FDRL0001968
# 17                             IDBI Bank     525104000462419  IBKL0000525
# 18                              UCO Bank      28430110056608  UCBA0000001
# ..                                   ...                 ...          ...
# 303                               Others            44963344          NaN
# 307                           ICICI Bank    KSCS034101003544  ICIC0000104
# 308                           ICICI Bank  MRCB10002001005429  ICIC0000104
# 309                           ICICI Bank                 nan          NaN
# 310                           ICICI Bank                 nan          NaN
#
#     cheque_no  mid  ...                                            remarks  \
# 14          0  NaN  ...  Necessary steps have been applied on the said ...
# 15          0  NaN  ...                                          DA 5000/-
# 16          0  NaN  ...                                                NaN
# 17          0  NaN  ...                                                NaN
# 18          0  NaN  ...  Necessary steps have been applied on the said ...
# ..        ...  ...  ...                                                ...
# 303         0  NaN  ...  Ecom/ONLYCHAIN   VILNIUS LT/425409861446/10092...
# 307         0  NaN  ...  UTR/UJVNH24250226541-Provide details are corre...
# 308         0  NaN  ...  UJVNH24250226510 -Provide details are correct ...
# 309         0  NaN  ...  Account no 626605011070 in which amount is cre...
# 310         0  NaN  ...  Account no 263601000172 in which amount is cre...
#
#                                         date_of_action  \
# 14    please reach out to us at notice_liabilitieso...
# 15                                 2024-09-22 17:53:32
# 16                                 2024-09-22 17:53:46
# 17                                 2024-09-22 17:55:16
# 18    please reach out to us at notice_liabilitieso...
# ..                                                 ...
# 303                                2024-09-26 20:53:51
# 307                                2024-09-27 16:06:15
# 308                                2024-09-27 16:08:51
# 309   Kindly Coordinate with mail id kolloorvilaban...
# 310   Kindly Coordinate with mail id MRCBMAILBOX@GM...
#
#                    action_taken_by_bank action_taken_name  \
# 14                  2024-09-22 17:52:21           AU Bank
# 15                              AU Bank   Abhishek Tiwari
# 16                  Bank of Maharashtra    Sushil Bhosale
# 17                  Bank of Maharashtra    Sushil Bhosale
# 18                  2024-09-22 17:56:58           AU Bank
# ..                                  ...               ...
# 303  Utkarsh Small Finance Bank Limited   Kailash Chandra
# 307      Ujjivan Small Finance Bank Ltd    Shivayogi Wali
# 308      Ujjivan Small Finance Bank Ltd    Shivayogi Wali
# 309                 2024-09-27 16:56:52        ICICI Bank
# 310                 2024-09-27 16:57:45        ICICI Bank
#
#              action_taken_by_email                    branch_location  \
# 14              Shiv Naryan. Swami               shiv.swami@aubank.in
# 15     abhishek.tiwari17@aubank.in                                NaN
# 16   sushil.bhosale@mahabank.co.in                                NaN
# 17   sushil.bhosale@mahabank.co.in                                NaN
# 18              Shiv Naryan. Swami               shiv.swami@aubank.in
# ..                             ...                                ...
# 303   kailash.chandra@utkarsh.bank                                NaN
# 307     shivayogi.wali@ujjivan.com                                NaN
# 308     shivayogi.wali@ujjivan.com                                NaN
# 309                Naveen Tripathi  naveen.tripathi@ext.icicibank.com
# 310                Naveen Tripathi  naveen.tripathi@ext.icicibank.com
#
#      branch_manager_name__contact_details unnamed_25 unnamed_26 unique_id
# 14                                    NaN        NaN        NaN        15
# 15                                    NaN        NaN        NaN        16
# 16                                    NaN        NaN        NaN        17
# 17                                    NaN        NaN        NaN        18
# 18                                    NaN        NaN        NaN        19
# ..                                    ...        ...        ...       ...
# 303                                   NaN        NaN        NaN       304
# 307                                   NaN        NaN        NaN       308
# 308                                   NaN        NaN        NaN       309
# 309                                   NaN        NaN        NaN       310
# 310                                   NaN        NaN        NaN       311
#
# [120 rows x 27 columns]
# ['110171398496' '746310110004930' '19680100099710' '525104000462419'
#  '28430110056608' '110171463270' '919376719291' '20200057674862'
#  '10111712000' '76851397' '76850584' '76854670' '76851639' '76852024'
#  'TERMINAL ID00009451' '9509421438mbk' 'TERMINAL ID00216882' 'nan'
#  '20200060398730' 'TERMINAL IDOMBIZKCY' '20200060040867' '110196874637'
#  '826101062106' '922010019482631' '110060209205' 'WPGTID01' '44963344'
#  'FDRL0SPCB01' '50100553312260' '50100277170880' '131451400002071'
#  'KSCS034101003544' 'MRCB10002001005429' 'TERMINAL' 'ID00009451'
#  'ID00216882' 'IDOMBIZKCY']
#     acknowledgement_no             transaction_id  layer  \
# 36      30209240022092               425066240046      4
# 37      30209240022092               425066240046      4
# 57      30209240022092               425611010344      4
# 69      30209240022092               425170086583      4
# 100     30209240022092               425016394782      4
# 104     30209240022092               425016319966      4
# 105     30209240022092               425016183681      4
# 106     30209240022092               419440664726      4
# 108     30209240022092               425627831563      4
# 112     30209240022092               462251367899      4
# 113     30209240022092               462251367899      4
# 114     30209240022092               462251367899      4
# 120     30209240022092               425016320009      4
# 129     30209240022092               425016256381      4
# 130     30209240022092               425016257328      4
# 132     30209240022092               425016147850      4
# 139     30209240022092               425616111220      4
# 145     30209240022092               462036699047      4
# 146     30209240022092               462031379613      4
# 155     30209240022092             OtrCyfe9snuywn      4
# 192     30209240022092               425066240046      4
# 193     30209240022092               425066240046      4
# 213     30209240022092               425611010344      4
# 227     30209240022092               425170086583      4
# 259     30209240022092               425016394782      4
# 263     30209240022092               425016319966      4
# 264     30209240022092               425016183681      4
# 265     30209240022092               419440664726      4
# 267     30209240022092               425627831563      4
# 271     30209240022092               462251367899      4
# 272     30209240022092               462251367899      4
# 273     30209240022092               462251367899      4
# 279     30209240022092               425016320009      4
# 287     30209240022092  425016256381 425016257328      4
# 289     30209240022092               425016147850      4
# 296     30209240022092               425616111220      4
# 301     30209240022092               462036699047      4
# 302     30209240022092               462031379613      4
# 311     30209240022092             OtrCyfe9snuywn      4
#
#                        to_account_no  \
# 36                   746310110004930
# 37                   746310110004930
# 57                       10111712000
# 69                      110171398496
# 100                  922010019482631
# 104                   19680100099710
# 105                   20570100056041
# 106                   50100553312260
# 108                   93040100011532
# 112                   50100277170880
# 113                   50100277170880
# 114                   50100277170880
# 120                  525104000462419
# 129  131451400002071 131451400002071
# 130  131451400002071 131451400002071
# 132                      10189224759
# 139                      35026356062
# 145                 2006104000039810
# 146                 2006104000039810
# 155                         76851639
# 192                  746310110004930
# 193                  746310110004930
# 213                      10111712000
# 227                     110171398496
# 259                  922010019482631
# 263                   19680100099710
# 264                   20570100056041
# 265                   50100553312260
# 267                   93040100011532
# 271                   50100277170880
# 272                   50100277170880
# 273                   50100277170880
# 279                  525104000462419
# 287  131451400002071 131451400002071
# 289                      10189224759
# 296                      35026356062
# 301                 2006104000039810
# 302                 2006104000039810
# 311                         76851639
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 36                                   Money Transfer to
# 37                                   Money Transfer to
# 57                                   Money Transfer to
# 69                                   Money Transfer to
# 100                                  Money Transfer to
# 104                                  Money Transfer to
# 105                             Withdrawal through ATM
# 106                                  Money Transfer to
# 108                            Transaction put on hold
# 112                            Transaction put on hold
# 113                                  Money Transfer to
# 114                                  Money Transfer to
# 120                                  Money Transfer to
# 129                                  Money Transfer to
# 130                                  Money Transfer to
# 132                                              Other
# 139                                              Other
# 145                             Withdrawal through ATM
# 146                             Withdrawal through ATM
# 155                                  Money Transfer to
# 192                                  Money Transfer to
# 193                                  Money Transfer to
# 213                                  Money Transfer to
# 227                                  Money Transfer to
# 259                                  Money Transfer to
# 263                                  Money Transfer to
# 264                             Withdrawal through ATM
# 265                                  Money Transfer to
# 267                            Transaction put on hold
# 271                            Transaction put on hold
# 272                                  Money Transfer to
# 273                                  Money Transfer to
# 279                                  Money Transfer to
# 287                                  Money Transfer to
# 289                                              Other
# 296                                              Other
# 301                             Withdrawal through ATM
# 302                             Withdrawal through ATM
# 311                                  Money Transfer to
#
#     bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 36                             IDBI Bank  2006104000039810  IBKL0002006
# 37                             IDBI Bank  2006104000039810  IBKL0002006
# 57                                Others      918955891544  PPIW0881822
# 69                              UCO Bank    28430110056608  UCBA0002843
# 100                         Federal Bank    20570100056041  FDRL0002057
# 104                         Indian Bank     19680100099710  IDIB000R103
# 105                         Federal Bank               nan          NaN
# 106               Jammu and Kashmir Bank    93040100011532  JAKA0SUNDEk
# 108               Jammu and Kashmir Bank               nan          NaN
# 112                            HDFC Bank               nan          NaN
# 113                  State Bank of India       35026356062  SBIN0002995
# 114                      Bank of Baroda      8430200000515  BARB0FATSIK
# 120                         Federal Bank    19680100099710  FDRL0001968
# 129                      IDFC First Bank       10189224759  IDFB0021852
# 130                      IDFC First Bank       10189224759  IDFB0021852
# 132                      IDFC First Bank               nan          NaN
# 139                  State Bank of India               nan          NaN
# 145                            IDBI Bank               nan          NaN
# 146                            IDBI Bank               nan          NaN
# 155                              AU Bank  XXXXXXXXXXXX7008          NaN
# 192                            IDBI Bank  2006104000039810  IBKL0002006
# 193                            IDBI Bank  2006104000039810  IBKL0002006
# 213                               Others      918955891544  PPIW0881822
# 227                             UCO Bank    28430110056608  UCBA0002843
# 259                         Federal Bank    20570100056041  FDRL0002057
# 263                         Indian Bank     19680100099710  IDIB000R103
# 264                         Federal Bank               nan          NaN
# 265               Jammu and Kashmir Bank    93040100011532  JAKA0SUNDEk
# 267               Jammu and Kashmir Bank               nan          NaN
# 271                            HDFC Bank               nan          NaN
# 272                  State Bank of India       35026356062  SBIN0002995
# 273                      Bank of Baroda      8430200000515  BARB0FATSIK
# 279                         Federal Bank    19680100099710  FDRL0001968
# 287                      IDFC First Bank       10189224759  IDFB0021852
# 289                      IDFC First Bank               nan          NaN
# 296                  State Bank of India               nan          NaN
# 301                            IDBI Bank               nan          NaN
# 302                            IDBI Bank               nan          NaN
# 311                              AU Bank  XXXXXXXXXXXX7008          NaN
#
#     cheque_no  mid  ...                                            remarks  \
# 36          0  NaN  ...                                       462031379613
# 37          0  NaN  ...                                       462036699047
# 57          0  NaN  ...  We have marked lien on account however funds I...
# 69          0  NaN  ...                                                NaN
# 100         0  NaN  ...                                         ISMAIL P K
# 104         0  NaN  ...      RTG/24250355868 Mr Shubham Banarji 7845881645
# 105         0  NaN  ...                                          9945 9946
# 106         0  NaN  ...                                                NaN
# 108         0  NaN  ...                                     DA put on hold
# 112         0  NaN  ...                        we marked hold fund Rs 3880
# 113         0  NaN  ...                                       425616111220
# 114         0  NaN  ...                                       425616110592
# 120         0  NaN  ...                                                  .
# 129         0  NaN  ...                                                NaN
# 130         0  NaN  ...                                                NaN
# 132         0  NaN  ...  We have marked lien on account however funds I...
# 139         0  NaN  ...         Hold Kept for the disputed amount Rs.10000
# 145         0  NaN  ...                       nfs/NAYALA JAIPUR BASSI RJIN
# 146         0  NaN  ...                       nfs/NAYALA JAIPUR BASSI RJIN
# 155         0  NaN  ...  Transaction was made toward Au Small Finance B...
# 192         0  NaN  ...                                       462031379613
# 193         0  NaN  ...                                       462036699047
# 213         0  NaN  ...  We have marked lien on account however funds I...
# 227         0  NaN  ...                                                NaN
# 259         0  NaN  ...                                         ISMAIL P K
# 263         0  NaN  ...      RTG/24250355868 Mr Shubham Banarji 7845881645
# 264         0  NaN  ...                                          9945 9946
# 265         0  NaN  ...                                                NaN
# 267         0  NaN  ...                                     DA put on hold
# 271         0  NaN  ...                        we marked hold fund Rs 3880
# 272         0  NaN  ...                                       425616111220
# 273         0  NaN  ...                                       425616110592
# 279         0  NaN  ...                                                  .
# 287         0  NaN  ...                                                NaN
# 289         0  NaN  ...  We have marked lien on account however funds I...
# 296         0  NaN  ...         Hold Kept for the disputed amount Rs.10000
# 301         0  NaN  ...                       nfs/NAYALA JAIPUR BASSI RJIN
# 302         0  NaN  ...                       nfs/NAYALA JAIPUR BASSI RJIN
# 311         0  NaN  ...  Transaction was made toward Au Small Finance B...
#
#                                         date_of_action  \
# 36                                 2024-09-22 18:08:42
# 37                                 2024-09-22 18:08:42
# 57                                 2024-09-22 18:50:48
# 69                                 2024-09-22 21:05:53
# 100                                2024-09-22 22:52:08
# 104                                2024-09-22 23:19:16
# 105                                2024-09-22 23:20:04
# 106                                2024-09-23 00:19:46
# 108                                2024-09-23 08:11:40
# 112                                2024-09-23 11:58:39
# 113                                2024-09-23 12:02:21
# 114                                2024-09-23 12:03:15
# 120                                2024-09-23 12:15:02
# 129                                2024-09-23 13:37:10
# 130                                2024-09-23 13:37:10
# 132   we shall share with you pos visa details in s...
# 139                                2024-09-23 17:04:20
# 145                                2024-09-24 16:12:48
# 146                                2024-09-24 16:16:35
# 155  Due to RBI guidelines we do not store any sens...
# 192                                2024-09-22 18:08:42
# 193                                2024-09-22 18:08:42
# 213                                2024-09-22 18:50:48
# 227                                2024-09-22 21:05:53
# 259                                2024-09-22 22:52:08
# 263                                2024-09-22 23:19:16
# 264                                2024-09-22 23:20:04
# 265                                2024-09-23 00:19:46
# 267                                2024-09-23 08:11:40
# 271                                2024-09-23 11:58:39
# 272                                2024-09-23 12:02:21
# 273                                2024-09-23 12:03:15
# 279                                2024-09-23 12:15:02
# 287                                2024-09-23 13:37:10
# 289   we shall share with you pos visa details in s...
# 296                                2024-09-23 17:04:20
# 301                                2024-09-24 16:12:48
# 302                                2024-09-24 16:16:35
# 311  Due to RBI guidelines we do not store any sens...
#
#                                   action_taken_by_bank  \
# 36                                       Bank of India
# 37                                       Bank of India
# 57                                     IDFC First Bank
# 69              Canara Bank (including Syndicate Bank)
# 100                                          Axis Bank
# 104                                       Federal Bank
# 105                                       Federal Bank
# 106                                          HDFC Bank
# 108                             Jammu and Kashmir Bank
# 112                                          HDFC Bank
# 113                                          HDFC Bank
# 114                                          HDFC Bank
# 120                                          IDBI Bank
# 129                                           Yes Bank
# 130                                           Yes Bank
# 132   Statement attached. customer mobile number 91...
# 139                                State Bank of India
# 145                                          IDBI Bank
# 146                                          IDBI Bank
# 155                                     account number
# 192                                      Bank of India
# 193                                      Bank of India
# 213                                    IDFC First Bank
# 227             Canara Bank (including Syndicate Bank)
# 259                                          Axis Bank
# 263                                       Federal Bank
# 264                                       Federal Bank
# 265                                          HDFC Bank
# 267                             Jammu and Kashmir Bank
# 271                                          HDFC Bank
# 272                                          HDFC Bank
# 273                                          HDFC Bank
# 279                                          IDBI Bank
# 287                                           Yes Bank
# 289   Statement attached. customer mobile number 91...
# 296                                State Bank of India
# 301                                          IDBI Bank
# 302                                          IDBI Bank
# 311                                     account number
#
#                                      action_taken_name  \
# 36                         Nodal Officer Bank Of India
# 37                         Nodal Officer Bank Of India
# 57                                  Neeraj Vishwakarma
# 69                      Cyber Police Coordinating Cell
# 100                                  Prajakta Kulkarni
# 104                                          Jayasurya
# 105                                          Jayasurya
# 106                                 Dilip Kumar Jangde
# 108                                    Yasir Azad Khan
# 112                                     Yukesh Kumar R
# 113                                     Yukesh Kumar R
# 114                                     Yukesh Kumar R
# 120                                  Shri Debasish Das
# 129                       Khushbu Lalchand Vishwakarma
# 130                       Khushbu Lalchand Vishwakarma
# 132                                2024-09-23 14:21:51
# 139                                    S V Vinod Kumar
# 145                                  Shri Anjani Verma
# 146                                  Shri Anjani Verma
# 155   full card number etc. Kindly do not reassign ...
# 192                        Nodal Officer Bank Of India
# 193                        Nodal Officer Bank Of India
# 213                                 Neeraj Vishwakarma
# 227                     Cyber Police Coordinating Cell
# 259                                  Prajakta Kulkarni
# 263                                          Jayasurya
# 264                                          Jayasurya
# 265                                 Dilip Kumar Jangde
# 267                                    Yasir Azad Khan
# 271                                     Yukesh Kumar R
# 272                                     Yukesh Kumar R
# 273                                     Yukesh Kumar R
# 279                                  Shri Debasish Das
# 287                       Khushbu Lalchand Vishwakarma
# 289                                2024-09-23 14:21:51
# 296                                    S V Vinod Kumar
# 301                                  Shri Anjani Verma
# 302                                  Shri Anjani Verma
# 311   full card number etc. Kindly do not reassign ...
#
#                    action_taken_by_email   branch_location  \
# 36          EFRMS.FRMD@bankofindia.co.in               NaN
# 37          EFRMS.FRMD@bankofindia.co.in               NaN
# 57                 LEA@idfcfirstbank.com               NaN
# 69                 blrccp@canarabank.com               NaN
# 100      Prajakta6.kulkarni@axisbank.com               NaN
# 104  jayasurya_fedserv@federalbank.co.in               NaN
# 105  jayasurya_fedserv@federalbank.co.in               NaN
# 106            dilip.jangde@hdfcbank.com               NaN
# 108               yasir.khan@jkbmail.com               NaN
# 112          yukeshkumar.r1@hdfcbank.com               NaN
# 113          yukeshkumar.r1@hdfcbank.com               NaN
# 114          yukeshkumar.r1@hdfcbank.com               NaN
# 120                debasish_d@idbi.co.in               NaN
# 129   khushbu.vishwakarma.ext@yesbank.in               NaN
# 130   khushbu.vishwakarma.ext@yesbank.in               NaN
# 132                      IDFC First Bank  Aniruddha Kamble
# 139             agmsrvl.lhoand@sbi.co.in               NaN
# 145              anjani.verma@idbi.co.in               NaN
# 146              anjani.verma@idbi.co.in               NaN
# 155                  2024-09-28 00:03:14              CRED
# 192         EFRMS.FRMD@bankofindia.co.in               NaN
# 193         EFRMS.FRMD@bankofindia.co.in               NaN
# ...
# 121                                  Money Transfer to
# 122                                  Money Transfer to
# 131                                  Money Transfer to
# 133                             Withdrawal through ATM
# 134                            Transaction put on hold
# 140                                  Money Transfer to
# 141                                  Money Transfer to
# 142                                  Money Transfer to
# 143                            Transaction put on hold
# 144                            Transaction put on hold
# 280                                  Money Transfer to
# 281                                  Money Transfer to
# 288                                  Money Transfer to
# 290                             Withdrawal through ATM
# 291                            Transaction put on hold
# 297                                  Money Transfer to
# 298                                  Money Transfer to
# 299                                  Money Transfer to
# 300                            Transaction put on hold
#
#     bank_wallet_pgpa_merchant__insurance from_account_no    ifsc_code  \
# 121                  Union Bank of India  49710100126457  ubin0804975
# 122                Punjab National Bank    5802413000113  PUNB0065700
# 131                            HDFC Bank  50100333973521  HDFC0001484
# 133                            HDFC Bank             nan          NaN
# 134                            HDFC Bank             nan          NaN
# 140                   Fino Payments Bank      3218000217  FINO0000001
# 141                   Fino Payments Bank      3218000217  FINO0000001
# 142                         Indian Bank       7845881645  IDIB000R103
# 143                   Fino Payments Bank             nan          NaN
# 144                   Fino Payments Bank             nan          NaN
# 280                  Union Bank of India  49710100126457  ubin0804975
# 281                Punjab National Bank    5802413000113  PUNB0065700
# 288                            HDFC Bank  50100333973521  HDFC0001484
# 290                            HDFC Bank             nan          NaN
# 291                            HDFC Bank             nan          NaN
# 297                   Fino Payments Bank      3218000217  FINO0000001
# 298                   Fino Payments Bank      3218000217  FINO0000001
# 299                         Indian Bank       7845881645  IDIB000R103
# 300                   Fino Payments Bank             nan          NaN
#
#     cheque_no  mid  ...                                            remarks  \
# 121         0  NaN  ...                                                NaN
# 122         0  NaN  ...                                                NaN
# 131         0  NaN  ...             We have marked lien on account however
# 133         0  NaN  ...                                2024-09-09 20:22:29
# 134         0  NaN  ...  NEFT CR-IDFB0010201-MR VIVEK SAHARAN-AMAN JHOR...
# 140         0  NaN  ...                                                NaN
# 141         0  NaN  ...                                                NaN
# 142         0  NaN  ...      RTG/24250355868 Mr Shubham Banarji 7845881645
# 143         0  NaN  ...                  S2 Payments UPI P2M Settlement GL
# 144         0  NaN  ...                  S2 Payments UPI P2M Settlement GL
# 280         0  NaN  ...                                                NaN
# 281         0  NaN  ...                                                NaN
# 288         0  NaN  ...             We have marked lien on account however
# 290         0  NaN  ...                                2024-09-09 20:22:29
# 291         0  NaN  ...  NEFT CR-IDFB0010201-MR VIVEK SAHARAN-AMAN JHOR...
# 297         0  NaN  ...                                                NaN
# 298         0  NaN  ...                                                NaN
# 299         0  NaN  ...      RTG/24250355868 Mr Shubham Banarji 7845881645
# 300         0  NaN  ...                  S2 Payments UPI P2M Settlement GL
#
#                                         date_of_action  \
# 121                                2024-09-23 12:38:59
# 122                                2024-09-23 12:39:51
# 131   disputed funds INR 5000/- has been transferre...
# 133                                2024-09-23 14:28:42
# 134                                2024-09-23 14:29:16
# 140                                2024-09-23 17:06:32
# 141                                2024-09-23 17:07:26
# 142                                2024-09-23 18:02:25
# 143                                2024-09-23 19:48:53
# 144                                2024-09-23 19:48:53
# 280                                2024-09-23 12:38:59
# 281                                2024-09-23 12:39:51
# 288   disputed funds INR 5000/- has been transferre...
# 290                                2024-09-23 14:28:42
# 291                                2024-09-23 14:29:16
# 297                                2024-09-23 17:06:32
# 298                                2024-09-23 17:07:26
# 299                                2024-09-23 18:02:25
# 300                                2024-09-23 19:48:53
#
#                                   action_taken_by_bank    action_taken_name  \
# 121  Bank of Baroda (Including Vijaya Bank and Dena...       Earnest Mary P
# 122  Bank of Baroda (Including Vijaya Bank and Dena...       Earnest Mary P
# 131   find attached account statement. Customer Mob...  2024-09-23 14:20:42
# 133                                          HDFC Bank         Mathumitha G
# 134                                          HDFC Bank         Mathumitha G
# 140                                State Bank of India      S V Vinod Kumar
# 141                                State Bank of India      S V Vinod Kumar
# 142                                       Federal Bank      Seethal S Kumar
# 143                                 Fino Payments Bank         Sarang Kadam
# 144                                 Fino Payments Bank         Sarang Kadam
# 280  Bank of Baroda (Including Vijaya Bank and Dena...       Earnest Mary P
# 281  Bank of Baroda (Including Vijaya Bank and Dena...       Earnest Mary P
# 288   find attached account statement. Customer Mob...  2024-09-23 14:20:42
# 290                                          HDFC Bank         Mathumitha G
# 291                                          HDFC Bank         Mathumitha G
# 297                                State Bank of India      S V Vinod Kumar
# 298                                State Bank of India      S V Vinod Kumar
# 299                                       Federal Bank      Seethal S Kumar
# 300                                 Fino Payments Bank         Sarang Kadam
#
#                  action_taken_by_email   branch_location  \
# 121            cc.i4c@bankofbaroda.com               NaN
# 122            cc.i4c@bankofbaroda.com               NaN
# 131                    IDFC First Bank  Aniruddha Kamble
# 133          mathumitha.g@hdfcbank.com               NaN
# 134          mathumitha.g@hdfcbank.com               NaN
# 140           agmsrvl.lhoand@sbi.co.in               NaN
# 141           agmsrvl.lhoand@sbi.co.in               NaN
# 142  seethal_fedserv@federalbank.co.in               NaN
# 143          sarang.kadam@finobank.com               NaN
# 144          sarang.kadam@finobank.com               NaN
# 280            cc.i4c@bankofbaroda.com               NaN
# 281            cc.i4c@bankofbaroda.com               NaN
# 288                    IDFC First Bank  Aniruddha Kamble
# 290          mathumitha.g@hdfcbank.com               NaN
# 291          mathumitha.g@hdfcbank.com               NaN
# 297           agmsrvl.lhoand@sbi.co.in               NaN
# 298           agmsrvl.lhoand@sbi.co.in               NaN
# 299  seethal_fedserv@federalbank.co.in               NaN
# 300          sarang.kadam@finobank.com               NaN
#
#      branch_manager_name__contact_details unnamed_25 unnamed_26 unique_id
# 121                                   NaN        NaN        NaN       122
# 122                                   NaN        NaN        NaN       123
# 131                 lea@idfcfirstbank.com        NaN        NaN       132
# 133                                   NaN        NaN        NaN       134
# 134                                   NaN        NaN        NaN       135
# 140                                   NaN        NaN        NaN       141
# 141                                   NaN        NaN        NaN       142
# 142                                   NaN        NaN        NaN       143
# 143                                   NaN        NaN        NaN       144
# 144                                   NaN        NaN        NaN       145
# 280                                   NaN        NaN        NaN       281
# 281                                   NaN        NaN        NaN       282
# 288                 lea@idfcfirstbank.com        NaN        NaN       289
# 290                                   NaN        NaN        NaN       291
# 291                                   NaN        NaN        NaN       292
# 297                                   NaN        NaN        NaN       298
# 298                                   NaN        NaN        NaN       299
# 299                                   NaN        NaN        NaN       300
# 300                                   NaN        NaN        NaN       301
#
# [19 rows x 27 columns]
# ['49710100126457' '5802413000113' '50100333973521' 'nan' '3218000217'
#  '7845881645']
#     acknowledgement_no transaction_id  layer   to_account_no  \
# 123     30209240022092   425684210028      6  49710100126457
# 124     30209240022092           4971      6  49710100125555
# 125     30209240022092   425617803879      6   5802413000113
# 282     30209240022092   425684210028      6  49710100126457
# 283     30209240022092           4971      6  49710100125555
# 284     30209240022092   425617803879      6   5802413000113
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 123                                  Money Transfer to
# 124                            Transaction put on hold
# 125                                  Money Transfer to
# 282                                  Money Transfer to
# 283                            Transaction put on hold
# 284                                  Money Transfer to
#
#     bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 123                  Union Bank of India    49710100125555  ubin0000001
# 124                  Union Bank of India               nan          NaN
# 125                     Karur Vysya Bank  1270178000033340  KVBL0000001
# 282                  Union Bank of India    49710100125555  ubin0000001
# 283                  Union Bank of India               nan          NaN
# 284                     Karur Vysya Bank  1270178000033340  KVBL0000001
#
#     cheque_no  mid  ...                                            remarks  \
# 123         0  NaN  ...                                                trf
# 124         0  NaN  ...                            account in debit freeze
# 125         0  NaN  ...  UPI/425687644580/P2A/1270178000033343@KVBL0000...
# 282         0  NaN  ...                                                trf
# 283         0  NaN  ...                            account in debit freeze
# 284         0  NaN  ...  UPI/425687644580/P2A/1270178000033343@KVBL0000...
#
#           date_of_action                               action_taken_by_bank  \
# 123  2024-09-23 13:02:09  Union Bank of India( including Andhra Bank and...
# 124  2024-09-23 13:04:14  Union Bank of India( including Andhra Bank and...
# 125  2024-09-23 13:20:46  Punjab National Bank (including Oriental Bank ...
# 282  2024-09-23 13:02:09  Union Bank of India( including Andhra Bank and...
# 283  2024-09-23 13:04:14  Union Bank of India( including Andhra Bank and...
# 284  2024-09-23 13:20:46  Punjab National Bank (including Oriental Bank ...
#
#     action_taken_name                     action_taken_by_email  \
# 123         G Radhika  gro.fgmovijayawada@unionbankofindia.bank
# 124         G Radhika  gro.fgmovijayawada@unionbankofindia.bank
# 125    M Krishna Naik                 zohydcybercrime@pnb.co.in
# 282         G Radhika  gro.fgmovijayawada@unionbankofindia.bank
# 283         G Radhika  gro.fgmovijayawada@unionbankofindia.bank
# 284    M Krishna Naik                 zohydcybercrime@pnb.co.in
#
#     branch_location  branch_manager_name__contact_details unnamed_25  \
# 123             NaN                                   NaN        NaN
# 124             NaN                                   NaN        NaN
# 125             NaN                                   NaN        NaN
# 282             NaN                                   NaN        NaN
# 283             NaN                                   NaN        NaN
# 284             NaN                                   NaN        NaN
#
#     unnamed_26 unique_id
# 123        NaN       124
# 124        NaN       125
# 125        NaN       126
# 282        NaN       283
# 283        NaN       284
# 284        NaN       285
#
# [6 rows x 27 columns]
# ['49710100125555' 'nan' '1270178000033340']
#     acknowledgement_no transaction_id  layer     to_account_no  \
# 137     30209240022092   425687644580      7  1270178000033340
# 138     30209240022092   462355061351      7   625702010005021
# 294     30209240022092   425687644580      7  1270178000033340
# 295     30209240022092   462355061351      7   625702010005021
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 137                                  Money Transfer to
# 138                            Transaction put on hold
# 294                                  Money Transfer to
# 295                            Transaction put on hold
#
#     bank_wallet_pgpa_merchant__insurance  from_account_no    ifsc_code  \
# 137                  Union Bank of India  625702010005021  UBIN0006257
# 138                  Union Bank of India              nan          NaN
# 294                  Union Bank of India  625702010005021  UBIN0006257
# 295                  Union Bank of India              nan          NaN
#
#     cheque_no  mid  ...                  remarks       date_of_action  \
# 137         0  NaN  ...                 DA 10000  2024-09-23 16:42:25
# 138         0  NaN  ...  account in debit freeze  2024-09-23 16:55:20
# 294         0  NaN  ...                 DA 10000  2024-09-23 16:42:25
# 295         0  NaN  ...  account in debit freeze  2024-09-23 16:55:20
#
#                                   action_taken_by_bank  action_taken_name  \
# 137                                   Karur Vysya Bank  Ms. Balagomathy A
# 138  Union Bank of India( including Andhra Bank and...          G Radhika
# 294                                   Karur Vysya Bank  Ms. Balagomathy A
# 295  Union Bank of India( including Andhra Bank and...          G Radhika
#
#                         action_taken_by_email branch_location  \
# 137                  balagomathya@kvbmail.com             NaN
# 138  gro.fgmovijayawada@unionbankofindia.bank             NaN
# 294                  balagomathya@kvbmail.com             NaN
# 295  gro.fgmovijayawada@unionbankofindia.bank             NaN
#
#      branch_manager_name__contact_details unnamed_25 unnamed_26 unique_id
# 137                                   NaN        NaN        NaN       138
# 138                                   NaN        NaN        NaN       139
# 294                                   NaN        NaN        NaN       295
# 295                                   NaN        NaN        NaN       296
#
# [4 rows x 27 columns]
# ['625702010005021' 'nan']

# %%
def format_amount_indian(amount):
    # Convert the amount to a string and remove any existing commas
    amount_str = str(amount).replace(',', '')
    
    # Check if the number has more than 3 digits
    if len(amount_str) > 3:
        # Get the last 3 digits
        last_three = amount_str[-3:]
        # Get the remaining digits
        remaining = amount_str[:-3]
        # Reverse the remaining digits for easier grouping
        remaining_reversed = remaining[::-1]
        # Group digits in thousands
        grouped = [remaining_reversed[i:i+2] for i in range(0, len(remaining_reversed), 2)]
        # Reverse and join the grouped digits with commas
        formatted_remaining = ','.join(grouped[::-1])
        # Concatenate the formatted remaining part with the last three digits
        formatted_amount = f'{formatted_remaining},{last_three}'
    else:
        # For amounts less than or equal to 999, no formatting is needed
        formatted_amount = amount_str

    return formatted_amount

# %%
ackno = df['acknowledgement_no'].unique()
ackname = 'Transaction Graph For (Ack No): ' + str(ackno)
ackname
# Out:
# "Transaction Graph For (Ack No): ['30209240022092']"

# %%
# Step 1: Retrieve Layer 1 records where "Money Transfer" occurs
layer1_records = df[(df['layer'] == 1) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
layer1_nodes = layer1_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date', 'amount', 'remarks']]

# Create a directed graph
G = nx.DiGraph()

# Add Layer 1 nodes (from_account_no as nodes, with details as attributes)
for _, row in layer1_nodes.iterrows():
    G.add_node(row['from_account_no'], 
               to_account=row['to_account_no'], 
               transaction_id=row['transaction_id'], 
               transaction_date=row['transaction_date'], 
               amount=row['amount'], 
               remarks=row['remarks'])

# Step 2: Retrieve Layer 2 records where "Money Transfer" occurs
layer2_records = df[(df['layer'] == 2) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
layer2_nodes = layer2_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date', 'amount', 'remarks']]

# Add Layer 2 nodes and connect edges based on "to_account_no" in Layer 2 matching "from_account_no" in Layer 1
for _, row in layer2_nodes.iterrows():
    # Find matching Layer 1 nodes where to_account_no equals from_account_no in Layer 2
    matching_layer1_nodes = layer1_nodes[layer1_nodes['from_account_no'] == row['to_account_no']]
    
    for _, layer1_row in matching_layer1_nodes.iterrows():
        # Add Layer 2 node
        G.add_node(row['from_account_no'], 
                   to_account=row['to_account_no'], 
                   transaction_id=row['transaction_id'], 
                   transaction_date=row['transaction_date'], 
                   amount=row['amount'], 
                   remarks=row['remarks'])
        
        # Add edges from Layer 1's from_account_no to Layer 2's from_account_no
        G.add_edge(layer1_row['from_account_no'], row['from_account_no'])

# Create elements for Dash Cytoscape
cyto_elements = []

# Custom positions to create an L-shape for edges
layer1_x = 100
layer2_x = 400  # Shift layer 2 nodes further right
y_increment = 100
current_y = 100

# Add nodes for Layer 1
layer1_node_positions = {}  # Keep track of node positions
for i, node in enumerate(G.nodes(data=True)):
    if node[1]['to_account'] in layer1_nodes['to_account_no'].values:  # Layer 1 nodes
        cyto_elements.append({
            'data': {'id': node[0], 'label': node[0]},  # node[0] is the node identifier (from_account_no)
            'position': {'x': layer1_x, 'y': current_y}  # Positioning for layer 1
        })
        layer1_node_positions[node[0]] = (layer1_x, current_y)  # Track Layer 1 node position for edges
        current_y += y_increment

# Reset y position for Layer 2
current_y = 100

# Add nodes for Layer 2 and edges
layer2_node_positions = {}  # Keep track of layer 2 node positions
for node in G.nodes(data=True):
    if node[1]['to_account'] not in layer1_nodes['to_account_no'].values:  # Layer 2 nodes
        cyto_elements.append({
            'data': {'id': node[0], 'label': node[0]},  # node[0] is the node identifier (from_account_no)
            'position': {'x': layer2_x, 'y': current_y}  # Positioning for layer 2
        })
        layer2_node_positions[node[0]] = (layer2_x, current_y)  # Track Layer 2 node position for edges
        current_y += y_increment

# Add edges between Layer 1 and Layer 2
for edge in G.edges():
    cyto_elements.append({
        'data': {'source': edge[0], 'target': edge[1]},
        'style': {'line-color': '#ff0000', 'width': 2, 'target-arrow-shape': 'triangle', 'arrow-color': '#0074D9'}
    })

# Initialize Dash app
app = JupyterDash(__name__)

app.layout = html.Div([
    cyto.Cytoscape(
        id='cytoscape-network',
        elements=cyto_elements,
        style={'width': '100%', 'height': '800px'},
        layout={'name': 'preset'},  # Use preset layout to keep positions defined
        stylesheet=[
            {'selector': 'node', 'style': {'content': 'data(label)', 'shape': 'rectangle', 'background-color': '#00ffD9'}},
            {'selector': 'edge', 'style': {'line-color': '#ff0000', 'curve-style': 'straight', 'target-arrow-shape': 'triangle'}}  # Straight edge styling
        ]
    )
])

if __name__ == '__main__':
    app.run_server(debug=True, port = 9099)
# Out:
# C:\Users\rjsri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\dash\dash.py:585: UserWarning:
#
# JupyterDash is deprecated, use Dash instead.
# See https://dash.plotly.com/dash-in-jupyter for more details.
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:9099/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Dash app running on http://127.0.0.1:9099/
