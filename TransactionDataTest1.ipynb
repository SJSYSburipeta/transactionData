# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import plotly.graph_objs as go
import re
from jupyter_dash import JupyterDash  # Use JupyterDash instead of dash.Dash
import dash
from dash import html
import dash_cytoscape as cyto

# %%
file_path = 'D:\\test\\ExcelManualCleaning.csv'
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    s_no acknowledgement_no           transaction_id  layer      to_account_no  \
# 0     1    `30209240022092  `PUNBR52024090612314232      2  `8830210000008880
# 1     2    `30209240022092  `PUNBR52024090612314232      2  `8830210000008880
# 2     3    `30209240022092  `PUNBR52024090612314232      2  `8830210000008880
# 3     4    `30209240022092  `PUNBR52024090612314232      2  `8830210000008880
# 4     5    `30209240022092  `PUNBR52024090612314232      2  `8830210000008880
#
#   action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 0                                  Money Transfer to
# 1                                  Money Transfer to
# 2                                  Money Transfer to
# 3                                  Money Transfer to
# 4                                  Money Transfer to
#
#   bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 0                         Federal Bank   `24610100000643  FDRL0001010
# 1                         Canara Bank      `110196345628  CNRB0004785
# 2                         Canara Bank      `110189607716  CNRB0004785
# 3                    South Indian Bank  `179053000017033  SIBL0000848
# 4                         Bandhan Bank   `20200057515505  BDBL0001815
#
#    cheque_no  ...  Unnamed: 29 Unnamed: 30  Unnamed: 31 Unnamed: 32  \
# 0          0  ...          NaN         NaN          NaN         NaN
# 1          0  ...          NaN         NaN          NaN         NaN
# 2          0  ...          NaN         NaN          NaN         NaN
# 3          0  ...          NaN         NaN          NaN         NaN
# 4          0  ...          NaN         NaN          NaN         NaN
#
#   Unnamed: 33 Unnamed: 34  Unnamed: 35  Unnamed: 36 Unnamed: 37 Unnamed: 38
# 0         NaN         NaN          NaN          NaN         NaN         NaN
# 1         NaN         NaN          NaN          NaN         NaN         NaN
# 2         NaN         NaN          NaN          NaN         NaN         NaN
# 3         NaN         NaN          NaN          NaN         NaN         NaN
# 4         NaN         NaN          NaN          NaN         NaN         NaN
#
# [5 rows x 39 columns]

# %%
df['amount']=df['amount'].astype(int)

# %%
df['layer'] = df['layer'].astype(int)

# %%
df = df.drop(['s_no'],axis=1)
# Remove text within square brackets
df['to_account_no'] = df['to_account_no'].str.replace(r'\s*\[.*?\]', '', regex=True)

# %%
# Define the columns to clean
columns_to_clean = [
    'acknowledgement_no', 'transaction_id', 'layer',
    'from_account_no', 'utr_number', 'amount','to_account_no'
]

# Function to clean data in a column
def clean_column_data(series):
    # Remove special characters and trim spaces
    series = series.apply(lambda x: re.sub(r'[^\w\s]', '', str(x)).strip() if pd.notna(x) else x)
    return series

# Apply the cleaning function to each specified column
for col in columns_to_clean:
    if col in df.columns:
        df[col] = clean_column_data(df[col])

# Display the cleaned data to verify
print(df[columns_to_clean].head())
# Out:
#   acknowledgement_no          transaction_id layer  from_account_no  \
# 0     30209240022092  PUNBR52024090612314232     2   24610100000643
# 1     30209240022092  PUNBR52024090612314232     2     110196345628
# 2     30209240022092  PUNBR52024090612314232     2     110189607716
# 3     30209240022092  PUNBR52024090612314232     2  179053000017033
# 4     30209240022092  PUNBR52024090612314232     2   20200057515505
#
#                utr_number  amount     to_account_no
# 0  DBSSR52024090605165954  270000  8830210000008880
# 1  DBSSR52024090605165914  200000  8830210000008880
# 2             CNRB0004785  399999  8830210000008880
# 3  DBSSR52024090605165915  371900  8830210000008880
# 4  DBSSR52024090605165951  290178  8830210000008880

# %%
df['unique_id'] = pd.Series(range(1, len(df) + 1))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 39 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   acknowledgement_no                                   156 non-null    object
#  1   transaction_id                                       156 non-null    object
#  2   layer                                                156 non-null    object
#  3   to_account_no                                        156 non-null    object
#  4   action_taken_by_bank_wallet_pgpa_merchant_insurance  156 non-null    object
#  5   bank_wallet_pgpa_merchant__insurance                 156 non-null    object
#  6   from_account_no                                      156 non-null    object
#  7   ifsc_code                                            96 non-null     object
#  8   cheque_no                                            156 non-null    int64
#  9   mid                                                  5 non-null      float64
#  10  tid                                                  5 non-null      object
#  11  approval_code                                        5 non-null      float64
#  12  merchant_name                                        5 non-null      object
#  13  transaction_date                                     156 non-null    object
#  14  utr_number                                           108 non-null    object
#  15  amount                                               156 non-null    object
#  16  reference_no                                         0 non-null      float64
#  17  remarks                                              118 non-null    object
#  18  date_of_action                                       156 non-null    object
#  19  action_taken_by_bank                                 156 non-null    object
#  20  action_taken_name                                    156 non-null    object
#  21  action_taken_by_email                                156 non-null    object
#  22  branch_location                                      21 non-null     object
#  23  branch_manager_name__contact_details                 8 non-null      object
#  24  unnamed_25                                           3 non-null      object
#  25  unnamed_26                                           1 non-null      object
#  26  Unnamed: 27                                          0 non-null      float64
#  27  Unnamed: 28                                          0 non-null      float64
#  28  Unnamed: 29                                          0 non-null      float64
#  29  Unnamed: 30                                          0 non-null      float64
#  30  Unnamed: 31                                          0 non-null      float64
#  31  Unnamed: 32                                          0 non-null      float64
#  32  Unnamed: 33                                          0 non-null      float64
#  33  Unnamed: 34                                          0 non-null      float64
#  34  Unnamed: 35                                          0 non-null      float64
#  35  Unnamed: 36                                          0 non-null      float64
#  36  Unnamed: 37                                          0 non-null      float64
#  37  Unnamed: 38                                          4 non-null      object
#  38  unique_id                                            156 non-null    int64
# dtypes: float64(14), int64(2), object(23)
# memory usage: 47.7+ KB

# %%
df['layer'] = pd.to_numeric(df['layer'], errors='coerce')
print(df['layer'].unique())
# Out:
# [2 3 1 4 5 6 7]

# %%
layers = df.groupby('layer')
layer1 = layers.get_group(1)
layer1
# Out:
#    acknowledgement_no          transaction_id  layer     to_account_no  \
# 21     30209240022092  SBINR52024090646591003      1  8830210000008880
# 34     30209240022092  PUNBR52024090612314232      1    10832030036580
# 38     30209240022092  PUNBR52024090612314232      1  8830210000008880
# 39     30209240022092  SBINR52024090646591003      1       10047593897
# 40     30209240022092                  965562      1       10047593897
# 41     30209240022092                  965563      1       10047593897
# 42     30209240022092                  965562      1       43017388358
# 43     30209240022092                  965563      1       43280321955
# 44     30209240022092             10047593897      1       43017388358
# 45     30209240022092             10047593897      1       43280321955
# 52     30209240022092  SBINR52024090646591003      1  8830210000008880
#
#    action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 21                            Transaction put on hold
# 34                                  Money Transfer to
# 38                                              Other
# 39                                  Money Transfer to
# 40                                  Money Transfer to
# 41                                  Money Transfer to
# 42                                              Other
# 43                                              Other
# 44                                              Other
# 45                                              Other
# 52                                              Other
#
#    bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 21                            DBS Bank   1146110010053650          NaN
# 34                            DBS Bank   8830210000008880  DBSS0IN0830
# 38                            DBS Bank                             NaN
# 39                            DBS Bank   8830210000008880  DBSS0IN0830
# 40                  State Bank of India       43017388358  SBIN0001464
# 41                  State Bank of India       43280321955  SBIN0011519
# 42                  State Bank of India                            NaN
# 43                  State Bank of India                            NaN
# 44                  State Bank of India                            NaN
# 45                  State Bank of India                            NaN
# 52                            DBS Bank                             NaN
#
#     cheque_no  mid  ... Unnamed: 30  Unnamed: 31 Unnamed: 32 Unnamed: 33  \
# 21          0  NaN  ...         NaN          NaN         NaN         NaN
# 34          0  NaN  ...         NaN          NaN         NaN         NaN
# 38          0  NaN  ...         NaN          NaN         NaN         NaN
# 39          0  NaN  ...         NaN          NaN         NaN         NaN
# 40          0  NaN  ...         NaN          NaN         NaN         NaN
# 41          0  NaN  ...         NaN          NaN         NaN         NaN
# 42          0  NaN  ...         NaN          NaN         NaN         NaN
# 43          0  NaN  ...         NaN          NaN         NaN         NaN
# 44          0  NaN  ...         NaN          NaN         NaN         NaN
# 45          0  NaN  ...         NaN          NaN         NaN         NaN
# 52          0  NaN  ...         NaN          NaN         NaN         NaN
#
#    Unnamed: 34 Unnamed: 35  Unnamed: 36 Unnamed: 37 Unnamed: 38 unique_id
# 21         NaN         NaN          NaN         NaN         NaN        22
# 34         NaN         NaN          NaN         NaN         NaN        35
# 38         NaN         NaN          NaN         NaN         NaN        39
# 39         NaN         NaN          NaN         NaN         NaN        40
# 40         NaN         NaN          NaN         NaN         NaN        41
# 41         NaN         NaN          NaN         NaN         NaN        42
# 42         NaN         NaN          NaN         NaN         NaN        43
# 43         NaN         NaN          NaN         NaN         NaN        44
# 44         NaN         NaN          NaN         NaN         NaN        45
# 45         NaN         NaN          NaN         NaN         NaN        46
# 52         NaN         NaN          NaN         NaN         NaN        53
#
# [11 rows x 39 columns]

# %%
# Assuming df contains your data
layers = df.groupby('layer')
for layer_num, layer_data in layers:
    # Get distinct account numbers
    print(layer_data)
    distinct_accounts = layer_data['from_account_no'].unique()
    print(distinct_accounts)
# Out:
#    acknowledgement_no          transaction_id  layer     to_account_no  \
# 21     30209240022092  SBINR52024090646591003      1  8830210000008880
# 34     30209240022092  PUNBR52024090612314232      1    10832030036580
# 38     30209240022092  PUNBR52024090612314232      1  8830210000008880
# 39     30209240022092  SBINR52024090646591003      1       10047593897
# 40     30209240022092                  965562      1       10047593897
# 41     30209240022092                  965563      1       10047593897
# 42     30209240022092                  965562      1       43017388358
# 43     30209240022092                  965563      1       43280321955
# 44     30209240022092             10047593897      1       43017388358
# 45     30209240022092             10047593897      1       43280321955
# 52     30209240022092  SBINR52024090646591003      1  8830210000008880
#
#    action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 21                            Transaction put on hold
# 34                                  Money Transfer to
# 38                                              Other
# 39                                  Money Transfer to
# 40                                  Money Transfer to
# 41                                  Money Transfer to
# 42                                              Other
# 43                                              Other
# 44                                              Other
# 45                                              Other
# 52                                              Other
#
#    bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 21                            DBS Bank   1146110010053650          NaN
# 34                            DBS Bank   8830210000008880  DBSS0IN0830
# 38                            DBS Bank                NaN          NaN
# 39                            DBS Bank   8830210000008880  DBSS0IN0830
# 40                  State Bank of India       43017388358  SBIN0001464
# 41                  State Bank of India       43280321955  SBIN0011519
# 42                  State Bank of India               NaN          NaN
# 43                  State Bank of India               NaN          NaN
# 44                  State Bank of India               NaN          NaN
# 45                  State Bank of India               NaN          NaN
# 52                            DBS Bank                NaN          NaN
#
#     cheque_no  mid  ...                                            remarks  \
# 21          0  NaN  ...                           Transaction put on hold.
# 34          0  NaN  ...  NRTGS/PUNBR52024090612314232/CRAVY MEALES ENTE...
# 38          0  NaN  ...                              Duplicate transaction
# 39          0  NaN  ...                      Transaction amount 2799952.80
# 40          0  NaN  ...                                                NaN
# 41          0  NaN  ...                                                NaN
# 42          0  NaN  ...  Account does not have sufficient balance. However
# 43          0  NaN  ...  Account does not have sufficient balance. However
# 44          0  NaN  ...    Repeated transaction. Action already initiated.
# 45          0  NaN  ...    Repeated transaction. Action already initiated.
# 52          0  NaN  ...                                  Already actioned.
#
#                                    date_of_action  \
# 21                               22-09-2024 17:59
# 34                               22-09-2024 18:06
# 38                               22-09-2024 18:10
# 39                               22-09-2024 18:13
# 40                               22-09-2024 18:18
# 41                               22-09-2024 18:19
# 42   Hold Kept for the disputed amount Rs.1100000
# 43   Hold Kept for the disputed amount Rs.1200000
# 44                               22-09-2024 18:20
# 45                               22-09-2024 18:20
# 52                               22-09-2024 18:30
#
#                                  action_taken_by_bank    action_taken_name  \
# 21            DBS Bank (Including Lakshmi Vilas Bank)     Akanksha Bhagade
# 34  Punjab National Bank (including Oriental Bank ...          Rahul Singh
# 38            DBS Bank (Including Lakshmi Vilas Bank)          Ajeet Kumar
# 39                                State Bank of India      S V Vinod Kumar
# 40                                State Bank of India      S V Vinod Kumar
# 41                                State Bank of India      S V Vinod Kumar
# 42                                   22-09-2024 18:19  State Bank of India
# 43                                   22-09-2024 18:19  State Bank of India
# 44                                State Bank of India      S V Vinod Kumar
# 45                                State Bank of India      S V Vinod Kumar
# 52            DBS Bank (Including Lakshmi Vilas Bank)     Akanksha Bhagade
#
#        action_taken_by_email           branch_location  \
# 21   akankshabhagade@dbs.com                       NaN
# 34      nccrpc.i4c@pnb.co.in                       NaN
# 38        ajeetkumar@dbs.com                       NaN
# 39  agmsrvl.lhoand@sbi.co.in                       NaN
# 40  agmsrvl.lhoand@sbi.co.in                       NaN
# 41  agmsrvl.lhoand@sbi.co.in                       NaN
# 42           S V Vinod Kumar  agmsrvl.lhoand@sbi.co.in
# 43           S V Vinod Kumar  agmsrvl.lhoand@sbi.co.in
# 44  agmsrvl.lhoand@sbi.co.in                       NaN
# 45  agmsrvl.lhoand@sbi.co.in                       NaN
# 52   akankshabhagade@dbs.com                       NaN
#
#     branch_manager_name__contact_details unnamed_25 unnamed_26 unique_id
# 21                                   NaN        NaN        NaN        22
# 34                                   NaN        NaN        NaN        35
# 38                                   NaN        NaN        NaN        39
# 39                                   NaN        NaN        NaN        40
# 40                                   NaN        NaN        NaN        41
# 41                                   NaN        NaN        NaN        42
# 42                                   NaN        NaN        NaN        43
# 43                                   NaN        NaN        NaN        44
# 44                                   NaN        NaN        NaN        45
# 45                                   NaN        NaN        NaN        46
# 52                                   NaN        NaN        NaN        53
#
# [11 rows x 27 columns]
# ['1146110010053650' '8830210000008880' nan '43017388358' '43280321955']
#     acknowledgement_no          transaction_id  layer     to_account_no  \
# 0       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 1       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 2       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 3       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 4       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 5       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 6       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 7       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 8       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 9       30209240022092  PUNBR52024090612314232      2  8830210000008880
# 10      30209240022092  PUNBR52024090612314232      2  8830210000008880
# 11      30209240022092  PUNBR52024090612314232      2  8830210000008880
# 12      30209240022092  PUNBR52024090612314232      2  8830210000008880
# 13      30209240022092  DBSSR52024090605165958      2  2401216960825130
# 22      30209240022092  SBINR52024090646591003      2  8830210000008880
# 23      30209240022092  SBINR52024090646591003      2  8830210000008880
# 24      30209240022092  SBINR52024090646591003      2  8830210000008880
# 25      30209240022092  SBINR52024090646591003      2  8830210000008880
# 26      30209240022092  SBINR52024090646591003      2  8830210000008880
# 30      30209240022092  DBSSR52024090605165916      2  2401227259431240
# 46      30209240022092                  965562      2       43017388358
# 47      30209240022092                  965562      2       43017388358
# 48      30209240022092                  965562      2       43017388358
# 49      30209240022092                  965562      2       43017388358
# 50      30209240022092                  965562      2       43017388358
# 51      30209240022092                  965562      2       43017388358
# 53      30209240022092                  965563      2       43280321955
# 54      30209240022092                  965563      2       43280321955
# 55      30209240022092                  965563      2       43280321955
# 56      30209240022092                  965563      2       43280321955
# 63      30209240022092  SBINR12024091047262739      2      110134809783
# 65      30209240022092  SBINR12024091047262739      2      110134809783
# 68      30209240022092        SBIN124254411029      2      110170638899
# 79      30209240022092  SBINR12024091247810781      2    22751400002853
# 85      30209240022092  DBSSR52024090605165918      2    21360100147753
# 86      30209240022092  DBSSR52024090605165954      2    24610100000643
# 88      30209240022092  DBSSR52024090605165954      2    24610100000643
# 89      30209240022092  DBSSR52024090605165954      2    24610100000643
# 91      30209240022092  DBSSR52024090605166673      2    24610100005204
# 92      30209240022092  DBSSR52024090605166673      2    24610100005204
# 93      30209240022092  DBSSR52024090605166673      2    24610100005204
# 95      30209240022092  DBSSR52024090605166706      2    18670100063718
# 97      30209240022092  DBSSR52024090605166706      2    18670100063718
# 101     30209240022092  SBINR12024091247810785      2   924010041487963
# 117     30209240022092  DBSSR52024090605165917      2  1607104000080370
# 118     30209240022092  DBSSR52024090605165917      2  1607104000080370
# 132     30209240022092  DBSSR52024090605165952      2    50100741696880
# 133     30209240022092  DBSSR52024090605165952      2    50100741696880
# 144     30209240022092  PUNBR52024090612314232      2  8830210000008880
# 145     30209240022092  DBSSR52024090605165952      2    50100741696880
# 146     30209240022092  PUNBR52024090612314232      2  8830210000008880
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 0                                    Money Transfer to
# 1                                    Money Transfer to
# 2                                    Money Transfer to
# 3                                    Money Transfer to
# 4                                    Money Transfer to
# 5                                    Money Transfer to
# 6                                    Money Transfer to
# 7                                    Money Transfer to
# 8                                    Money Transfer to
# 9                                    Money Transfer to
# 10                                   Money Transfer to
# 11                                   Money Transfer to
# 12                                   Money Transfer to
# 13                      Cash Withdrawal through Cheque
# 22                                   Money Transfer to
# 23                                   Money Transfer to
# 24                                   Money Transfer to
# 25                                   Money Transfer to
# 26                                   Money Transfer to
# 30                      Cash Withdrawal through Cheque
# 46                                   Money Transfer to
# 47                                   Money Transfer to
# 48                                   Money Transfer to
# 49                                   Money Transfer to
# 50                                   Money Transfer to
# 51                                   Money Transfer to
# 53                                   Money Transfer to
# 54                                   Money Transfer to
# 55                                   Money Transfer to
# 56                                   Money Transfer to
# 63                              Withdrawal through ATM
# 65                              Withdrawal through ATM
# 68                              Withdrawal through ATM
# 79                                               Other
# 85                              Withdrawal through ATM
# 86                              Withdrawal through ATM
# 88                              Withdrawal through ATM
# 89                                               Other
# 91                              Withdrawal through ATM
# 92                              Withdrawal through ATM
# 93                                               Other
# 95                              Withdrawal through ATM
# 97                                               Other
# 101                             Withdrawal through ATM
# 117                             Withdrawal through ATM
# 118                             Withdrawal through ATM
# 132                             Withdrawal through POS
# 133                             Withdrawal through POS
# 144                                  Money Transfer to
# 145                             Withdrawal through POS
# 146                                  Money Transfer to
#
#     bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 0                           Federal Bank    24610100000643  FDRL0001010
# 1                           Canara Bank       110196345628  CNRB0004785
# 2                           Canara Bank       110189607716  CNRB0004785
# 3                      South Indian Bank   179053000017033  SIBL0000848
# 4                           Bandhan Bank    20200057515505  BDBL0001815
# 5                           Bandhan Bank    20200059779220  BDBL0001592
# 6                                AU Bank  2401216960825130  AUBL0002556
# 7                              IDBI Bank  1607104000080370  IBKL0001648
# 8                           Federal Bank    21360100147753  FDRL0001010
# 9                                AU Bank  2401227259431240  AUBL0002556
# 10                          Bandhan Bank    20200059117762  BDBL0001815
# 11                   Bank of Maharashtra       60496115000  MAHB0000005
# 12                   Bank of Maharashtra       60501402002  MAHB0000005
# 13                               AU Bank  2401216960825130  AUBL0002163
# 22        Ujjivan Small Finance Bank Ltd  1146110010053650  UJVN0001146
# 23                          Bandhan Bank    20200050694941  BDBL0001592
# 24                          Federal Bank    18670100063718  FDRL0001759
# 25                          Federal Bank    24610100005204  FDRL0001759
# 26                            ICICI Bank       79801513015  ICIC0000798
# 30                               AU Bank  2401227259431240  AUBL0002272
# 46                          Canara Bank       110170638899  CNRB0007447
# 47                          Bandhan Bank    20200060776541  BDBL0001557
# 48                          Bandhan Bank    20200060503423  BDBL0001797
# 49    Utkarsh Small Finance Bank Limited  1564019694617840  UTKS0001564
# 50                          Canara Bank       110134809783  CNRB0006641
# 51                          Bandhan Bank    20200060530420  BDBL0001480
# 53                          Federal Bank     1001014000220  FDRL0SPCB01
# 54                              Yes Bank    22751400002853  YESB0000227
# 55                          Bandhan Bank    20200058727202  BDBL0001518
# 56                             Axis Bank   924010041487963  UTIB0002882
# 63                          Canara Bank                NaN          NaN
# 65                          Canara Bank                NaN          NaN
# 68                          Canara Bank                NaN          NaN
# 79                              Yes Bank               NaN          NaN
# 85                          Federal Bank   922010019482631          NaN
# 86                          Federal Bank          WPGTID01          NaN
# 88                          Federal Bank          WPGTID01          NaN
# 89                          Federal Bank               NaN          NaN
# 91                          Federal Bank          44963344          NaN
# 92                          Federal Bank          44963344          NaN
# 93                          Federal Bank               NaN          NaN
# 95                          Federal Bank          WPGTID01          NaN
# 97                          Federal Bank               NaN          NaN
# 101                            Axis Bank    50100277170880          NaN
# 117                            IDBI Bank               NaN          NaN
# 118                            IDBI Bank   131451400002071          NaN
# 132                            HDFC Bank               NaN          NaN
# 133                            HDFC Bank               NaN          NaN
# 144                            HDFC Bank    50100741696880  HDFC0000365
# 145                            HDFC Bank               NaN          NaN
# 146   Utkarsh Small Finance Bank Limited  1564017023043730  UTKS0001564
#
#      cheque_no           mid  ...  \
# 0            0           NaN  ...
# 1            0           NaN  ...
# 2            0           NaN  ...
# 3            0           NaN  ...
# 4            0           NaN  ...
# 5            0           NaN  ...
# 6            0           NaN  ...
# 7            0           NaN  ...
# 8            0           NaN  ...
# 9            0           NaN  ...
# 10           0           NaN  ...
# 11           0           NaN  ...
# 12           0           NaN  ...
# 13           4           NaN  ...
# 22           0           NaN  ...
# 23           0           NaN  ...
# 24           0           NaN  ...
# 25           0           NaN  ...
# 26           0           NaN  ...
# 30          13           NaN  ...
# 46           0           NaN  ...
# 47           0           NaN  ...
# 48           0           NaN  ...
# 49           0           NaN  ...
# 50           0           NaN  ...
# 51           0           NaN  ...
# 53           0           NaN  ...
# 54           0           NaN  ...
# 55           0           NaN  ...
# 56           0           NaN  ...
# 63           0           NaN  ...
# 65           0           NaN  ...
# 68           0           NaN  ...
# 79           0           NaN  ...
# 85           0           NaN  ...
# 86           0           NaN  ...
# 88           0           NaN  ...
# 89           0           NaN  ...
# 91           0           NaN  ...
# 92           0           NaN  ...
# 93           0           NaN  ...
# 95           0           NaN  ...
# 97           0           NaN  ...
# 101          0           NaN  ...
# 117          0           NaN  ...
# 118          0           NaN  ...
# 132          0  1.144000e+14  ...
# 133          0  2.006010e+11  ...
# 144          0           NaN  ...
# 145          0  2.006010e+11  ...
# 146          0           NaN  ...
#
#                                                remarks  \
# 0                        RTGS 0830OI4005165954 BHUPESH
# 1                      RTGS 0830OI4005165914 JUNJA RAM
# 2                       RTGS 0830OI4005165956 AKBARALI
# 3           RTGS 0830OI4005165915 SHAIKH MOHAMMEDSAJID
# 4                         RTGS 0830OI4005165951 KISHOR
# 5                      RTGS 0830OI4005165959 ACHALARAM
# 6              RTGS 0830OI4005165958 ASHOK KUMAR MEENA
# 7                     RTGS 0830OI4005165917 RAVI KUMAR
# 8                       RTGS 0830OI4005165918 ANAM C P
# 9                     RTGS 0830OI4005165916 ARBAJ KHAN
# 10                RTGS 0830OI4005165913 VIRENDRA KUMAR
# 11         RTGS 0830OI4005165955 MR MUSHTAK KHAN KARIM
# 12         RTGS 0830OI4005165953 SEJAL VASUDEV MESHRAM
# 13                                         DA 245000/-
# 22       RTGS 0830OI4005166760 MUHAMMED SHYAM SHAJAHAN
# 23                      RTGS 0830OI4005166704 RAMKUMAR
# 24                        RTGS 0830OI4005166706 BIJITH
# 25                     RTGS 0830OI4005166673 AKBAR ALI
# 26                  RTGS 0830OI4005166705 CHETAN KUMAR
# 30   Necessary steps have been applied on the said ...
# 46                                                 NaN
# 47                                                 NaN
# 48                                                 NaN
# 49                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 53                                                 NaN
# 54                                                 NaN
# 55                                                 NaN
# 56                                                 NaN
# 63   DA SI RS.75000. TRASNACTION TIME IS FROM 03:45...
# 65   DA IS RS.100000. TRASNACTION TIME IS FROM 03:4...
# 68                                          DA SI RS96
# 79   12-Sep-2024 3:39 PM / CHQ PAID TO SELF-NARNAUL...
# 85   425016701817 425016701818 425016701819 4250167...
# 86                                           3348 3349
# 88                           425016062804 425016071778
# 89                                         ECM CHARGES
# 91                                         4.25018E+23
# 92              425017018980 425017031916 425017018752
# 93                                         ECM CHARGES
# 95   425017726523 425017726524 425017726525 4250177...
# 97                                         ECM CHARGES
# 101                                          DA- 36657
# 117                                                  .
# 118                                                  .
# 132                                        4.25011E+11
# 133                                425012256134 DA 181
# 144  RTGS 0830OI4005165952 MOHD MUZAFFERAMEENUDDIN(...
# 145                                   0830OI4005165952
# 146               RTGS 0830OI4005165962 VIKASH BISHNOI
#
#                                         date_of_action  \
# 0                                     22-09-2024 17:46
# 1                                     22-09-2024 17:46
# 2                                     22-09-2024 17:46
# 3                                     22-09-2024 17:46
# 4                                     22-09-2024 17:46
# 5                                     22-09-2024 17:46
# 6                                     22-09-2024 17:46
# 7                                     22-09-2024 17:46
# 8                                     22-09-2024 17:46
# 9                                     22-09-2024 17:46
# 10                                    22-09-2024 17:46
# 11                                    22-09-2024 17:46
# 12                                    22-09-2024 17:46
# 13                                    22-09-2024 17:52
# 22                                    22-09-2024 17:59
# 23                                    22-09-2024 17:59
# 24                                    22-09-2024 17:59
# 25                                    22-09-2024 17:59
# 26                                    22-09-2024 17:59
# 30    please reach out to us at notice_liabilitieso...
# 46                                    22-09-2024 18:24
# 47                                    22-09-2024 18:25
# 48                                    22-09-2024 18:26
# 49                                    22-09-2024 18:27
# 50                                    22-09-2024 18:28
# 51                                    22-09-2024 18:29
# 53                                    22-09-2024 18:31
# 54                                    22-09-2024 18:32
# 55                                    22-09-2024 18:33
# 56                                    22-09-2024 18:35
# 63                                    22-09-2024 21:03
# 65                                    22-09-2024 21:03
# 68                                              582.55
# 79                                    22-09-2024 22:19
# 85                                    22-09-2024 22:33
# 86                                    22-09-2024 22:37
# 88                                    22-09-2024 22:37
# 89                                    22-09-2024 22:37
# 91                                    22-09-2024 22:44
# 92                                    22-09-2024 22:44
# 93                                    22-09-2024 22:45
# 95                                    22-09-2024 22:48
# 97                                    22-09-2024 22:49
# 101                                   22-09-2024 23:03
# 117                                   23-09-2024 12:09
# 118                                   23-09-2024 12:09
# 132                                   23-09-2024 14:58
# 133                                   23-09-2024 14:59
# 144                                   26-09-2024 23:33
# 145                                   27-09-2024 00:07
# 146                                   27-09-2024 12:18
#
#                         action_taken_by_bank  \
# 0    DBS Bank (Including Lakshmi Vilas Bank)
# 1    DBS Bank (Including Lakshmi Vilas Bank)
# 2    DBS Bank (Including Lakshmi Vilas Bank)
# 3    DBS Bank (Including Lakshmi Vilas Bank)
# 4    DBS Bank (Including Lakshmi Vilas Bank)
# 5    DBS Bank (Including Lakshmi Vilas Bank)
# 6    DBS Bank (Including Lakshmi Vilas Bank)
# 7    DBS Bank (Including Lakshmi Vilas Bank)
# 8    DBS Bank (Including Lakshmi Vilas Bank)
# 9    DBS Bank (Including Lakshmi Vilas Bank)
# 10   DBS Bank (Including Lakshmi Vilas Bank)
# 11   DBS Bank (Including Lakshmi Vilas Bank)
# 12   DBS Bank (Including Lakshmi Vilas Bank)
# 13                                   AU Bank
# 22   DBS Bank (Including Lakshmi Vilas Bank)
# 23   DBS Bank (Including Lakshmi Vilas Bank)
# 24   DBS Bank (Including Lakshmi Vilas Bank)
# 25   DBS Bank (Including Lakshmi Vilas Bank)
# 26   DBS Bank (Including Lakshmi Vilas Bank)
# 30                          22-09-2024 18:03
# 46                       State Bank of India
# 47                       State Bank of India
# 48                       State Bank of India
# 49                       State Bank of India
# 50                       State Bank of India
# 51                       State Bank of India
# 53                       State Bank of India
# 54                       State Bank of India
# 55                       State Bank of India
# 56                       State Bank of India
# 63    Canara Bank (including Syndicate Bank)
# 65    Canara Bank (including Syndicate Bank)
# 68                          22-09-2024 21:05
# 79                                  Yes Bank
# 85                              Federal Bank
# 86                              Federal Bank
# 88                              Federal Bank
# 89                              Federal Bank
# 91                              Federal Bank
# 92                              Federal Bank
# 93                              Federal Bank
# 95                              Federal Bank
# 97                              Federal Bank
# 101                                Axis Bank
# 117                                IDBI Bank
# 118                                IDBI Bank
# 132                                HDFC Bank
# 133                                HDFC Bank
# 144  DBS Bank (Including Lakshmi Vilas Bank)
# 145                                HDFC Bank
# 146  DBS Bank (Including Lakshmi Vilas Bank)
#
#                           action_taken_name  \
# 0                          Akanksha Bhagade
# 1                          Akanksha Bhagade
# 2                          Akanksha Bhagade
# 3                          Akanksha Bhagade
# 4                          Akanksha Bhagade
# 5                          Akanksha Bhagade
# 6                          Akanksha Bhagade
# 7                          Akanksha Bhagade
# 8                          Akanksha Bhagade
# 9                          Akanksha Bhagade
# 10                         Akanksha Bhagade
# 11                         Akanksha Bhagade
# 12                         Akanksha Bhagade
# 13                          Abhishek Tiwari
# 22                         Akanksha Bhagade
# 23                         Akanksha Bhagade
# 24                         Akanksha Bhagade
# 25                         Akanksha Bhagade
# 26                         Akanksha Bhagade
# 30                                  AU Bank
# 46                          S V Vinod Kumar
# 47                          S V Vinod Kumar
# 48                          S V Vinod Kumar
# 49                          S V Vinod Kumar
# 50                          S V Vinod Kumar
# 51                          S V Vinod Kumar
# 53                          S V Vinod Kumar
# 54                          S V Vinod Kumar
# 55                          S V Vinod Kumar
# 56                          S V Vinod Kumar
# 63           Cyber Police Coordinating Cell
# 65           Cyber Police Coordinating Cell
# 68   Canara Bank (including Syndicate Bank)
# 79                            Divya Chauhan
# 85                                Jayasurya
# 86                                Jayasurya
# 88                                Jayasurya
# 89                                Jayasurya
# 91                                Jayasurya
# 92                                Jayasurya
# 93                                Jayasurya
# 95                                Jayasurya
# 97                                Jayasurya
# 101                       Prajakta Kulkarni
# 117                       Shri Debasish Das
# 118                       Shri Debasish Das
# 132                          Yukesh Kumar R
# 133                          Yukesh Kumar R
# 144                          Tanmay Kumbhar
# 145                         Sikander Sharma
# 146                        Akanksha Bhagade
#
#                    action_taken_by_email  \
# 0                akankshabhagade@dbs.com
# 1                akankshabhagade@dbs.com
# 2                akankshabhagade@dbs.com
# 3                akankshabhagade@dbs.com
# 4                akankshabhagade@dbs.com
# 5                akankshabhagade@dbs.com
# 6                akankshabhagade@dbs.com
# 7                akankshabhagade@dbs.com
# 8                akankshabhagade@dbs.com
# 9                akankshabhagade@dbs.com
# 10               akankshabhagade@dbs.com
# 11               akankshabhagade@dbs.com
# 12               akankshabhagade@dbs.com
# 13           abhishek.tiwari17@aubank.in
# 22               akankshabhagade@dbs.com
# 23               akankshabhagade@dbs.com
# 24               akankshabhagade@dbs.com
# 25               akankshabhagade@dbs.com
# 26               akankshabhagade@dbs.com
# 30                    Shiv Naryan. Swami
# 46              agmsrvl.lhoand@sbi.co.in
# 47              agmsrvl.lhoand@sbi.co.in
# 48              agmsrvl.lhoand@sbi.co.in
# 49              agmsrvl.lhoand@sbi.co.in
# 50              agmsrvl.lhoand@sbi.co.in
# 51              agmsrvl.lhoand@sbi.co.in
# 53              agmsrvl.lhoand@sbi.co.in
# 54              agmsrvl.lhoand@sbi.co.in
# 55              agmsrvl.lhoand@sbi.co.in
# 56              agmsrvl.lhoand@sbi.co.in
# 63                 blrccp@canarabank.com
# 65                 blrccp@canarabank.com
# 68        Cyber Police Coordinating Cell
# 79             divya.chauhan1@yesbank.in
# 85   jayasurya_fedserv@federalbank.co.in
# 86   jayasurya_fedserv@federalbank.co.in
# 88   jayasurya_fedserv@federalbank.co.in
# 89   jayasurya_fedserv@federalbank.co.in
# 91   jayasurya_fedserv@federalbank.co.in
# 92   jayasurya_fedserv@federalbank.co.in
# 93   jayasurya_fedserv@federalbank.co.in
# 95   jayasurya_fedserv@federalbank.co.in
# 97   jayasurya_fedserv@federalbank.co.in
# 101      Prajakta6.kulkarni@axisbank.com
# 117                debasish_d@idbi.co.in
# 118                debasish_d@idbi.co.in
# 132          yukeshkumar.r1@hdfcbank.com
# 133          yukeshkumar.r1@hdfcbank.com
# 144                tanmaykumbhar@dbs.com
# 145         sikandra.sharma@hdfcbank.com
# 146              akankshabhagade@dbs.com
#
#                                        branch_location  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13   C-55,Subh Laxmi Near Maharishi Arvind Institut...
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 30                                shiv.swami@aubank.in
# 46                                                 NaN
# 47                                                 NaN
# 48                                                 NaN
# 49                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 53                                                 NaN
# 54                                                 NaN
# 55                                                 NaN
# 56                                                 NaN
# 63                                                 NaN
# 65                                                 NaN
# 68                               blrccp@canarabank.com
# 79                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 95                                                 NaN
# 97                                                 NaN
# 101                                                NaN
# 117                                                NaN
# 118                                                NaN
# 132                                                NaN
# 133                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
#                   branch_manager_name__contact_details  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# 5                                                  NaN
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                        Mr. Ankit Sharma  8905111731
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 30   Duggar Vidyalaya road, Opposite Terapant Bhawa...
# 46                                                 NaN
# 47                                                 NaN
# 48                                                 NaN
# 49                                                 NaN
# 50                                                 NaN
# 51                                                 NaN
# 53                                                 NaN
# 54                                                 NaN
# 55                                                 NaN
# 56                                                 NaN
# 63                                                 NaN
# 65                                                 NaN
# 68                                                 NaN
# 79                                                 NaN
# 85                                                 NaN
# 86                                                 NaN
# 88                                                 NaN
# 89                                                 NaN
# 91                                                 NaN
# 92                                                 NaN
# 93                                                 NaN
# 95                                                 NaN
# 97                                                 NaN
# 101                                                NaN
# 117                                                NaN
# 118                                                NaN
# 132                                                NaN
# 133                                                NaN
# 144                                                NaN
# 145                                                NaN
# 146                                                NaN
#
#                            unnamed_25 unnamed_26 unique_id
# 0                                 NaN        NaN         1
# 1                                 NaN        NaN         2
# 2                                 NaN        NaN         3
# 3                                 NaN        NaN         4
# 4                                 NaN        NaN         5
# 5                                 NaN        NaN         6
# 6                                 NaN        NaN         7
# 7                                 NaN        NaN         8
# 8                                 NaN        NaN         9
# 9                                 NaN        NaN        10
# 10                                NaN        NaN        11
# 11                                NaN        NaN        12
# 12                                NaN        NaN        13
# 13                                NaN        NaN        14
# 22                                NaN        NaN        23
# 23                                NaN        NaN        24
# 24                                NaN        NaN        25
# 25                                NaN        NaN        26
# 26                                NaN        NaN        27
# 30   Mr. Poonam Chand Sahu,9116181205        NaN        31
# 46                                NaN        NaN        47
# 47                                NaN        NaN        48
# 48                                NaN        NaN        49
# 49                                NaN        NaN        50
# 50                                NaN        NaN        51
# 51                                NaN        NaN        52
# 53                                NaN        NaN        54
# 54                                NaN        NaN        55
# 55                                NaN        NaN        56
# 56                                NaN        NaN        57
# 63                                NaN        NaN        64
# 65                                NaN        NaN        66
# 68                                NaN        NaN        69
# 79                                NaN        NaN        80
# 85                                NaN        NaN        86
# 86                                NaN        NaN        87
# 88                                NaN        NaN        89
# 89                                NaN        NaN        90
# 91                                NaN        NaN        92
# 92                                NaN        NaN        93
# 93                                NaN        NaN        94
# 95                                NaN        NaN        96
# 97                                NaN        NaN        98
# 101                               NaN        NaN       102
# 117                               NaN        NaN       118
# 118                               NaN        NaN       119
# 132                               NaN        NaN       133
# 133                               NaN        NaN       134
# 144                               NaN        NaN       145
# 145                               NaN        NaN       146
# 146                               NaN        NaN       147
#
# [51 rows x 27 columns]
# ['24610100000643' '110196345628' '110189607716' '179053000017033'
#  '20200057515505' '20200059779220' '2401216960825130' '1607104000080370'
#  '21360100147753' '2401227259431240' '20200059117762' '60496115000'
#  '60501402002' '1146110010053650' '20200050694941' '18670100063718'
#  '24610100005204' '79801513015' '110170638899' '20200060776541'
#  '20200060503423' '1564019694617840' '110134809783' '20200060530420'
#  '1001014000220' '22751400002853' '20200058727202' '924010041487963' nan
#  '922010019482631' 'WPGTID01' '44963344' '50100277170880'
#  '131451400002071' '50100741696880' '1564017023043730']
#     acknowledgement_no             transaction_id  layer     to_account_no  \
# 14      30209240022092     DBSSR52024090605165916      3  2401227259431240
# 15      30209240022092     DBSSR52024090605165958      3  2401216960825130
# 16      30209240022092     DBSSR52024090605165955      3       60496115000
# 17      30209240022092     DBSSR52024090605165953      3       60501402002
# 18      30209240022092     DBSSR52024090605165916      3  2401227259431240
# ..                 ...                        ...    ...               ...
# 157     30209240022092     DBSSR52024090605165914      3      110196345628
# 158     30209240022092     DBSSR52024090605165914      3      110196345628
# 159     30209240022092     DBSSR52024090605165914      3      110196345628
# 160     30209240022092     DBSSR52024090605165914      3      110196345628
# 161     30209240022092  425016256381 425016257328      3   131451400002071
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 14                                   Money Transfer to
# 15                                   Money Transfer to
# 16                                   Money Transfer to
# 17                                   Money Transfer to
# 18                                   Money Transfer to
# ..                                                 ...
# 157                                  Money Transfer to
# 158                                  Money Transfer to
# 159                                  Money Transfer to
# 160                                  Money Transfer to
# 161                             Withdrawal through POS
#
#     bank_wallet_pgpa_merchant__insurance  from_account_no    ifsc_code  \
# 14                          Canara Bank      110171398496  CNRB0000001
# 15                         Bank of India  746310110004930  BKID0000001
# 16                          Federal Bank   19680100099710  FDRL0001968
# 17                             IDBI Bank  525104000462419  IBKL0000525
# 18                              UCO Bank   28430110056608  UCBA0000001
# ..                                   ...              ...          ...
# 157                             Mobikwik         TERMINAL  CNRB0000000
# 158                             Mobikwik       IDOMBIZKCY  CNRB0000000
# 159                             Mobikwik         TERMINAL  BDBL0002429
# 160                             Mobikwik       IDOMBIZKCY  BDBL0002429
# 161                             Yes Bank              NaN          NaN
#
#      cheque_no         mid  ...  \
# 14           0         NaN  ...
# 15           0         NaN  ...
# 16           0         NaN  ...
# 17           0         NaN  ...
# 18           0         NaN  ...
# ..         ...         ...  ...
# 157          0         NaN  ...
# 158          0         NaN  ...
# 159          0         NaN  ...
# 160          0         NaN  ...
# 161          0  89054820.0  ...
#
#                                                remarks  \
# 14   Necessary steps have been applied on the said ...
# 15                                           DA 5000/-
# 16                                                 NaN
# 17                                                 NaN
# 18   Necessary steps have been applied on the said ...
# ..                                                 ...
# 157  CARD NO- 652340XXXXXX5542. MERCHANT NAME- ONEM...
# 158  CARD NO- 652340XXXXXX5542. MERCHANT NAME- ONEM...
# 159   CARD NO- 652340XXXXXX5542. APPROVAL CODE- 286474
# 160   CARD NO- 652340XXXXXX5542. APPROVAL CODE- 286474
# 161                                              20000
#
#                                         date_of_action  \
# 14    please reach out to us at notice_liabilitieso...
# 15                                    22-09-2024 17:53
# 16                                    22-09-2024 17:53
# 17                                    22-09-2024 17:55
# 18    please reach out to us at notice_liabilitieso...
# ..                                                 ...
# 157                                   22-09-2024 21:13
# 158                                   22-09-2024 21:13
# 159                                   22-09-2024 21:13
# 160                                   22-09-2024 21:13
# 161                                   23-09-2024 13:35
#
#                        action_taken_by_bank               action_taken_name  \
# 14                         22-09-2024 17:52                         AU Bank
# 15                                  AU Bank                 Abhishek Tiwari
# 16                      Bank of Maharashtra                  Sushil Bhosale
# 17                      Bank of Maharashtra                  Sushil Bhosale
# 18                         22-09-2024 17:56                         AU Bank
# ..                                      ...                             ...
# 157  Canara Bank (including Syndicate Bank)  Cyber Police Coordinating Cell
# 158  Canara Bank (including Syndicate Bank)  Cyber Police Coordinating Cell
# 159  Canara Bank (including Syndicate Bank)  Cyber Police Coordinating Cell
# 160  Canara Bank (including Syndicate Bank)  Cyber Police Coordinating Cell
# 161                                Yes Bank    Khushbu Lalchand Vishwakarma
#
#                   action_taken_by_email       branch_location  \
# 14                   Shiv Naryan. Swami  shiv.swami@aubank.in
# ...
# 136                                   23-09-2024 17:04
# 141                                   24-09-2024 16:12
# 142                                   24-09-2024 16:16
# 151  Due to RBI guidelines we do not store any sens...
# 162                                   23-09-2024 13:37
#
#                                   action_taken_by_bank  \
# 36                                       Bank of India
# 37                                       Bank of India
# 57                                     IDFC First Bank
# 69              Canara Bank (including Syndicate Bank)
# 99                                           Axis Bank
# 103                                       Federal Bank
# 104                                       Federal Bank
# 105                                          HDFC Bank
# 107                             Jammu and Kashmir Bank
# 111                                          HDFC Bank
# 112                                          HDFC Bank
# 113                                          HDFC Bank
# 119                                          IDBI Bank
# 127                                           Yes Bank
# 129   Statement attached. customer mobile number 91...
# 136                                State Bank of India
# 141                                          IDBI Bank
# 142                                          IDBI Bank
# 151                                     account number
# 162                                           Yes Bank
#
#                                      action_taken_name  \
# 36                         Nodal Officer Bank Of India
# 37                         Nodal Officer Bank Of India
# 57                                  Neeraj Vishwakarma
# 69                      Cyber Police Coordinating Cell
# 99                                   Prajakta Kulkarni
# 103                                          Jayasurya
# 104                                          Jayasurya
# 105                                 Dilip Kumar Jangde
# 107                                    Yasir Azad Khan
# 111                                     Yukesh Kumar R
# 112                                     Yukesh Kumar R
# 113                                     Yukesh Kumar R
# 119                                  Shri Debasish Das
# 127                       Khushbu Lalchand Vishwakarma
# 129                                   23-09-2024 14:21
# 136                                    S V Vinod Kumar
# 141                                  Shri Anjani Verma
# 142                                  Shri Anjani Verma
# 151   full card number etc. Kindly do not reassign ...
# 162                       Khushbu Lalchand Vishwakarma
#
#                    action_taken_by_email   branch_location  \
# 36          EFRMS.FRMD@bankofindia.co.in               NaN
# 37          EFRMS.FRMD@bankofindia.co.in               NaN
# 57                 LEA@idfcfirstbank.com               NaN
# 69                 blrccp@canarabank.com               NaN
# 99       Prajakta6.kulkarni@axisbank.com               NaN
# 103  jayasurya_fedserv@federalbank.co.in               NaN
# 104  jayasurya_fedserv@federalbank.co.in               NaN
# 105            dilip.jangde@hdfcbank.com               NaN
# 107               yasir.khan@jkbmail.com               NaN
# 111          yukeshkumar.r1@hdfcbank.com               NaN
# 112          yukeshkumar.r1@hdfcbank.com               NaN
# 113          yukeshkumar.r1@hdfcbank.com               NaN
# 119                debasish_d@idbi.co.in               NaN
# 127   khushbu.vishwakarma.ext@yesbank.in               NaN
# 129                      IDFC First Bank  Aniruddha Kamble
# 136             agmsrvl.lhoand@sbi.co.in               NaN
# 141              anjani.verma@idbi.co.in               NaN
# 142              anjani.verma@idbi.co.in               NaN
# 151                     28-09-2024 00:03              CRED
# 162   khushbu.vishwakarma.ext@yesbank.in               NaN
#
#      branch_manager_name__contact_details      unnamed_25 unnamed_26 unique_id
# 36                                    NaN             NaN        NaN        37
# 37                                    NaN             NaN        NaN        38
# 57                                    NaN             NaN        NaN        58
# 69                                    NaN             NaN        NaN        70
# 99                                    NaN             NaN        NaN       100
# 103                                   NaN             NaN        NaN       104
# 104                                   NaN             NaN        NaN       105
# 105                                   NaN             NaN        NaN       106
# 107                                   NaN             NaN        NaN       108
# 111                                   NaN             NaN        NaN       112
# 112                                   NaN             NaN        NaN       113
# 113                                   NaN             NaN        NaN       114
# 119                                   NaN             NaN        NaN       120
# 127                                   NaN             NaN        NaN       128
# 129                 lea@idfcfirstbank.com             NaN        NaN       130
# 136                                   NaN             NaN        NaN       137
# 141                                   NaN             NaN        NaN       142
# 142                                   NaN             NaN        NaN       143
# 151                        Jaghadish Goud  risk@cred.club        NaN       152
# 162                                   NaN             NaN        NaN       163
#
# [20 rows x 27 columns]
# ['2006104000039810' '918955891544' '28430110056608' '20570100056041'
#  '19680100099710' nan '93040100011532' '35026356062' '8430200000515'
#  '10189224759' 'XXXXXXXXXXXX7008']
#     acknowledgement_no             transaction_id  layer  \
# 120     30209240022092               425616110592      5
# 121     30209240022092               425616110592      5
# 128     30209240022092               425016147850      5
# 130     30209240022092           IDFBH24250919697      5
# 131     30209240022092           IDFBH24250919697      5
# 137     30209240022092               425616111220      5
# 138     30209240022092               425616111220      5
# 139     30209240022092               425016255680      5
# 140     30209240022092               425736666462      5
# 163     30209240022092  425736666462 425747417995      5
#
#              to_account_no  \
# 120          8430200000515
# 121          8430200000515
# 128            10189224759
# 130         50100333973521
# 131         50100333973521
# 137            35026356062
# 138            35026356062
# 139         19680100099710
# 140             3218000217
# 163  3218000217 3218000217
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 120                                  Money Transfer to
# 121                                  Money Transfer to
# 128                                  Money Transfer to
# 130                             Withdrawal through ATM
# 131                            Transaction put on hold
# 137                                  Money Transfer to
# 138                                  Money Transfer to
# 139                                  Money Transfer to
# 140                            Transaction put on hold
# 163                            Transaction put on hold
#
#     bank_wallet_pgpa_merchant__insurance from_account_no    ifsc_code  \
# 120                  Union Bank of India  49710100126457  ubin0804975
# 121                Punjab National Bank    5802413000113  PUNB0065700
# 128                            HDFC Bank  50100333973521  HDFC0001484
# 130                            HDFC Bank             NaN          NaN
# 131                            HDFC Bank             NaN          NaN
# 137                   Fino Payments Bank      3218000217  FINO0000001
# 138                   Fino Payments Bank      3218000217  FINO0000001
# 139                         Indian Bank       7845881645  IDIB000R103
# 140                   Fino Payments Bank             NaN          NaN
# 163                   Fino Payments Bank             NaN          NaN
#
#      cheque_no  mid  ...                                            remarks  \
# 120          0  NaN  ...                                                NaN
# 121          0  NaN  ...                                                NaN
# 128          0  NaN  ...             We have marked lien on account however
# 130          0  NaN  ...                                   09-09-2024 20:22
# 131          0  NaN  ...  NEFT CR-IDFB0010201-MR VIVEK SAHARAN-AMAN JHOR...
# 137          0  NaN  ...                                                NaN
# 138          0  NaN  ...                                                NaN
# 139          0  NaN  ...      RTG/24250355868 Mr Shubham Banarji 7845881645
# 140          0  NaN  ...                  S2 Payments UPI P2M Settlement GL
# 163          0  NaN  ...                  S2 Payments UPI P2M Settlement GL
#
#                                         date_of_action  \
# 120                                   23-09-2024 12:38
# 121                                   23-09-2024 12:39
# 128   disputed funds INR 5000/- has been transferre...
# 130                                   23-09-2024 14:28
# 131                                   23-09-2024 14:29
# 137                                   23-09-2024 17:06
# 138                                   23-09-2024 17:07
# 139                                   23-09-2024 18:02
# 140                                   23-09-2024 19:48
# 163                                   23-09-2024 19:48
#
#                                   action_taken_by_bank action_taken_name  \
# 120  Bank of Baroda (Including Vijaya Bank and Dena...    Earnest Mary P
# 121  Bank of Baroda (Including Vijaya Bank and Dena...    Earnest Mary P
# 128   find attached account statement. Customer Mob...  23-09-2024 14:20
# 130                                          HDFC Bank      Mathumitha G
# 131                                          HDFC Bank      Mathumitha G
# 137                                State Bank of India   S V Vinod Kumar
# 138                                State Bank of India   S V Vinod Kumar
# 139                                       Federal Bank   Seethal S Kumar
# 140                                 Fino Payments Bank      Sarang Kadam
# 163                                 Fino Payments Bank      Sarang Kadam
#
#                  action_taken_by_email   branch_location  \
# 120            cc.i4c@bankofbaroda.com               NaN
# 121            cc.i4c@bankofbaroda.com               NaN
# 128                    IDFC First Bank  Aniruddha Kamble
# 130          mathumitha.g@hdfcbank.com               NaN
# 131          mathumitha.g@hdfcbank.com               NaN
# 137           agmsrvl.lhoand@sbi.co.in               NaN
# 138           agmsrvl.lhoand@sbi.co.in               NaN
# 139  seethal_fedserv@federalbank.co.in               NaN
# 140          sarang.kadam@finobank.com               NaN
# 163          sarang.kadam@finobank.com               NaN
#
#      branch_manager_name__contact_details unnamed_25 unnamed_26 unique_id
# 120                                   NaN        NaN        NaN       121
# 121                                   NaN        NaN        NaN       122
# 128                 lea@idfcfirstbank.com        NaN        NaN       129
# 130                                   NaN        NaN        NaN       131
# 131                                   NaN        NaN        NaN       132
# 137                                   NaN        NaN        NaN       138
# 138                                   NaN        NaN        NaN       139
# 139                                   NaN        NaN        NaN       140
# 140                                   NaN        NaN        NaN       141
# 163                                   NaN        NaN        NaN       164
#
# [10 rows x 27 columns]
# ['49710100126457' '5802413000113' '50100333973521' nan '3218000217'
#  '7845881645']
#     acknowledgement_no transaction_id  layer   to_account_no  \
# 122     30209240022092   425684210028      6  49710100126457
# 123     30209240022092           4971      6  49710100125555
# 124     30209240022092   425617803879      6   5802413000113
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 122                                  Money Transfer to
# 123                            Transaction put on hold
# 124                                  Money Transfer to
#
#     bank_wallet_pgpa_merchant__insurance   from_account_no    ifsc_code  \
# 122                  Union Bank of India    49710100125555  ubin0000001
# 123                  Union Bank of India               NaN          NaN
# 124                     Karur Vysya Bank  1270178000033340  KVBL0000001
#
#      cheque_no  mid  ...                                            remarks  \
# 122          0  NaN  ...                                                trf
# 123          0  NaN  ...                            account in debit freeze
# 124          0  NaN  ...  UPI/425687644580/P2A/1270178000033343@KVBL0000...
#
#        date_of_action                               action_taken_by_bank  \
# 122  23-09-2024 13:02  Union Bank of India( including Andhra Bank and...
# 123  23-09-2024 13:04  Union Bank of India( including Andhra Bank and...
# 124  23-09-2024 13:20  Punjab National Bank (including Oriental Bank ...
#
#     action_taken_name                     action_taken_by_email  \
# 122         G Radhika  gro.fgmovijayawada@unionbankofindia.bank
# 123         G Radhika  gro.fgmovijayawada@unionbankofindia.bank
# 124    M Krishna Naik                 zohydcybercrime@pnb.co.in
#
#     branch_location  branch_manager_name__contact_details unnamed_25  \
# 122             NaN                                   NaN        NaN
# 123             NaN                                   NaN        NaN
# 124             NaN                                   NaN        NaN
#
#     unnamed_26 unique_id
# 122        NaN       123
# 123        NaN       124
# 124        NaN       125
#
# [3 rows x 27 columns]
# ['49710100125555' nan '1270178000033340']
#     acknowledgement_no transaction_id  layer     to_account_no  \
# 134     30209240022092   425687644580      7  1270178000033340
# 135     30209240022092   462355061351      7   625702010005021
#
#     action_taken_by_bank_wallet_pgpa_merchant_insurance  \
# 134                                  Money Transfer to
# 135                            Transaction put on hold
#
#     bank_wallet_pgpa_merchant__insurance  from_account_no    ifsc_code  \
# 134                  Union Bank of India  625702010005021  UBIN0006257
# 135                  Union Bank of India              NaN          NaN
#
#      cheque_no  mid  ...                  remarks    date_of_action  \
# 134          0  NaN  ...                 DA 10000  23-09-2024 16:42
# 135          0  NaN  ...  account in debit freeze  23-09-2024 16:55
#
#                                   action_taken_by_bank  action_taken_name  \
# 134                                   Karur Vysya Bank  Ms. Balagomathy A
# 135  Union Bank of India( including Andhra Bank and...          G Radhika
#
#                         action_taken_by_email branch_location  \
# 134                  balagomathya@kvbmail.com             NaN
# 135  gro.fgmovijayawada@unionbankofindia.bank             NaN
#
#      branch_manager_name__contact_details unnamed_25 unnamed_26 unique_id
# 134                                   NaN        NaN        NaN       135
# 135                                   NaN        NaN        NaN       136
#
# [2 rows x 27 columns]
# ['625702010005021' nan]

# %%
def format_amount_indian(amount):
    # Convert the amount to a string and remove any existing commas
    amount_str = str(amount).replace(',', '')
    
    # Check if the number has more than 3 digits
    if len(amount_str) > 3:
        # Get the last 3 digits
        last_three = amount_str[-3:]
        # Get the remaining digits
        remaining = amount_str[:-3]
        # Reverse the remaining digits for easier grouping
        remaining_reversed = remaining[::-1]
        # Group digits in thousands (group of 2 after the first group of 3)
        grouped = [remaining_reversed[i:i+2] for i in range(0, len(remaining_reversed), 2)]
        # Reverse and join the grouped digits with commas
        formatted_remaining = ','.join(grouped[::-1]).lstrip('0')  # lstrip removes any leading zeroes
        # Concatenate the formatted remaining part with the last three digits
        formatted_amount = f'{formatted_remaining},{last_three}' if formatted_remaining else last_three
    else:
        # For amounts less than or equal to 999, no formatting is needed
        formatted_amount = amount_str

    return formatted_amount

# %%
ackno = df['acknowledgement_no'].unique()
ackname = 'Transaction Graph For (Ack No): ' + str(ackno)
ackname
# Out:
# "Transaction Graph For (Ack No): ['30209240022092']"

# %%
layer1_records = df[(df['layer'] == 1) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
layer1_nodes = layer1_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date','ifsc_code', 'amount', 'remarks']]

layer1_nodes
# Out:
#      from_account_no   to_account_no          transaction_id  \
# 34  8830210000008880  10832030036580  PUNBR52024090612314232
# 39  8830210000008880     10047593897  SBINR52024090646591003
# 40       43017388358     10047593897                  965562
# 41       43280321955     10047593897                  965563
#
#     transaction_date    ifsc_code   amount  \
# 34  06-09-2024 11:00  DBSS0IN0830  4100000
# 39  06-09-2024 16:49  DBSS0IN0830  2799952
# 40  10-09-2024 13:02  SBIN0001464  1100000
# 41  12-09-2024 00:00  SBIN0011519  1200000
#
#                                               remarks
# 34  NRTGS/PUNBR52024090612314232/CRAVY MEALES ENTE...
# 39                      Transaction amount 2799952.80
# 40                                                NaN
# 41                                                NaN

# %%
from graphviz import Digraph

# Create a directed graph using Graphviz with hierarchical layout
dot = Digraph()

# Set the graph layout to be hierarchical (left-right) and use L-shaped edges
dot.attr(rankdir='LR', splines='ortho')

# Get the distinct unique layers from the dataset
layers = sorted(df['layer'].unique())

# Initialize the previous layer nodes (starting with an empty set)
previous_layer_nodes = None

# Set to track already added edges to avoid duplicates
added_edges = set()

# Loop through each distinct layer in the dataset
for idx, layer in enumerate(layers):
    
    # Step 1: For the first layer, apply Money Transfer filter
    if idx == 0:
        layer_records = df[(df['layer'] == layer) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
    # Step 2: For other layers, only filter by layer
    else:
        layer_records = df[df['layer'] == layer]

    # Select relevant columns from the filtered dataset
    layer_nodes = layer_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date', 'ifsc_code', 'amount', 'remarks', 'action_taken_by_bank_wallet_pgpa_merchant_insurance']]
    
    # Add nodes for the current layer (from_account_no as nodes, with rectangular shape)
    for _, row in layer_nodes.iterrows():
        # Default color is black
        node_color = 'black'
        
        # Change node color if 'WITHDRAWAL' is in action_taken_by_bank_wallet_pgpa_merchant_insurance
        if 'WITHDRAWAL' in row['action_taken_by_bank_wallet_pgpa_merchant_insurance'].upper():
            node_color = '#0000ff'  # Blue color for withdrawal
            
        # Change node color if 'ON HOLD' is in action_taken_by_bank_wallet_pgpa_merchant_insurance
        elif 'ON HOLD' in row['action_taken_by_bank_wallet_pgpa_merchant_insurance'].upper():
            node_color = '#ff0000'  # Red color for on hold
        
        # Add node with the specific color and rectangular shape
        dot.node(
            str(row['from_account_no']), 
            label=f"Acc: {row['from_account_no']}\nTransID: {row['transaction_id']}\nIFSC Code: {row['ifsc_code']}\nAmount: {format_amount_indian(row['amount'])}", 
            shape='box',
            color=node_color
        )

    # If this is not the first layer, add edges between the previous layer and the current one
    if previous_layer_nodes is not None:
        # Add edges based on "to_account_no" in the current layer matching "from_account_no" in the previous layer
        for _, row in layer_nodes.iterrows():
            matching_previous_layer_nodes = previous_layer_nodes[previous_layer_nodes['from_account_no'] == row['to_account_no']]
            
            for _, prev_row in matching_previous_layer_nodes.iterrows():
                # Create an identifier for the edge to check for duplicates
                edge = (str(prev_row['from_account_no']), str(row['from_account_no']))
                
                # Add edge if it hasn't been added yet
                if edge not in added_edges:
                    # Add L-shaped edge from the previous layer's from_account_no to the current layer's from_account_no
                    dot.edge(str(prev_row['from_account_no']), str(row['from_account_no']), label=f"Transfer on {row['transaction_date']}")
                    added_edges.add(edge)  # Track the added edge

    # Set the current layer as the previous layer for the next iteration
    previous_layer_nodes = layer_nodes

# Save and view the graph (optional)
dot.render('dfs_transaction_graph', format='png', cleanup=True)
dot.view()
# Out:
# Warning: Orthogonal edges do not currently handle edge labels. Try using xlabels.
# Warning: Orthogonal edges do not currently handle edge labels. Try using xlabels.
# 'dfs_transaction_graph.pdf'

# %%
from graphviz import Digraph

# Create a directed graph using Graphviz with hierarchical layout
dot = Digraph()

# Set the graph layout to be hierarchical (left-right) and use L-shaped edges
dot.attr(rankdir='LR', splines='ortho')

# Get the distinct unique layers from the dataset
layers = sorted(df['layer'].unique())

# Initialize the previous layer nodes (starting with an empty set)
previous_layer_nodes = None

# Loop through each distinct layer in the dataset
for layer in layers:
    # Step 1: Retrieve records for the current layer where "Money Transfer" occurs
    layer_records = df[(df['layer'] == layer) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
    layer_nodes = layer_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date', 'ifsc_code', 'amount', 'remarks']]
    
    # Add nodes for the current layer (from_account_no as nodes, with rectangular shape)
    for _, row in layer_nodes.iterrows():
        dot.node(str(row['from_account_no']), label=f"Acc: {row['from_account_no']}\nTransID: {row['transaction_id']}\nIFSC Code: {row['ifsc_code']}\nAmount: {format_amount_indian(row['amount'])}", shape='box')

    # If this is not the first layer, add edges between the previous layer and the current one
    if previous_layer_nodes is not None:
        # Add edges based on "to_account_no" in the current layer matching "from_account_no" in the previous layer
        for _, row in layer_nodes.iterrows():
            matching_previous_layer_nodes = previous_layer_nodes[previous_layer_nodes['from_account_no'] == row['to_account_no']]
            
            for _, prev_row in matching_previous_layer_nodes.iterrows():
                # Add L-shaped edge from the previous layer's from_account_no to the current layer's from_account_no
                dot.edge(str(prev_row['from_account_no']), str(row['from_account_no']), label=f"Transfer on {row['transaction_date']}")

    # Set the current layer as the previous layer for the next iteration
    previous_layer_nodes = layer_nodes

# Save and view the graph (optional)
dot.render('dfs_transaction_graph', format='png', cleanup=True)
dot.view()
# Out:
# Warning: Orthogonal edges do not currently handle edge labels. Try using xlabels.
# Warning: Orthogonal edges do not currently handle edge labels. Try using xlabels.
# 'dfs_transaction_graph.pdf'

# %%
from graphviz import Digraph

# Create a directed graph using Graphviz with hierarchical layout
dot = Digraph()

# Set the graph layout to be hierarchical (top-down) and use L-shaped edges
dot.attr(rankdir='LR', splines='ortho')

# Step 1: Retrieve Layer 1 records where "Money Transfer" occurs
layer1_records = df[(df['layer'] == 1) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
layer1_nodes = layer1_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date','ifsc_code', 'amount', 'remarks']]

# Add Layer 1 nodes (from_account_no as nodes, with rectangular shape)
for _, row in layer1_nodes.iterrows():
    dot.node(str(row['from_account_no']), label=f"Acc: {row['from_account_no']}\nTransID: {row['transaction_id']}\nIFSC Code: {row['ifsc_code']}\nAmount: {format_amount_indian(row['amount'])}", shape='box')

# Step 2: Retrieve Layer 2 records where "Money Transfer" occurs
layer2_records = df[(df['layer'] == 2) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
layer2_nodes = layer2_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date','ifsc_code', 'amount', 'remarks']]

# Add Layer 2 nodes and connect edges based on "to_account_no" in Layer 2 matching "from_account_no" in Layer 1
for _, row in layer2_nodes.iterrows():
    # Find matching Layer 1 nodes where to_account_no equals from_account_no in Layer 2
    matching_layer1_nodes = layer1_nodes[layer1_nodes['from_account_no'] == row['to_account_no']]
    
    for _, layer1_row in matching_layer1_nodes.iterrows():
        # Add Layer 2 node with rectangular shape
        dot.node(str(row['from_account_no']), label=f"Acc: {row['from_account_no']}\nTransID: {row['transaction_id']}\nIFSC Code: {row['ifsc_code']}\nAmount: {format_amount_indian(row['amount'])}", shape='box')
        
        # Add L-shaped edge from Layer 1's from_account_no to Layer 2's from_account_no
        dot.edge(str(layer1_row['from_account_no']), str(row['from_account_no']), label=f"Transfer on {row['transaction_date']}\nAmount: {format_amount_indian(row['amount'])}")

# Step 3: Retrieve Layer 3 records where "Money Transfer" occurs
layer3_records = df[(df['layer'] == 3) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
layer3_nodes = layer3_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date','ifsc_code', 'amount', 'remarks']]

# Add Layer 3 nodes and connect edges based on "to_account_no" in Layer 3 matching "from_account_no" in Layer 2
for _, row in layer3_nodes.iterrows():
    # Find matching Layer 2 nodes where to_account_no equals from_account_no in Layer 3
    matching_layer2_nodes = layer2_nodes[layer2_nodes['from_account_no'] == row['to_account_no']]
    
    for _, layer2_row in matching_layer2_nodes.iterrows():
        # Add Layer 3 node with rectangular shape
        dot.node(str(row['from_account_no']), label=f"Acc: {row['from_account_no']}\nTransID: {row['transaction_id']}\nIFSC Code: {row['ifsc_code']}\nAmount: {format_amount_indian(row['amount'])}", shape='box')
        
        # Add L-shaped edge from Layer 2's from_account_no to Layer 3's from_account_no
        dot.edge(str(layer2_row['from_account_no']), str(row['from_account_no']), label=f"Transfer on {row['transaction_date']}\nAmount: {format_amount_indian(row['amount'])}")

# Save and view the graph (optional)
dot.render('dfs_transaction_graph', format='png', cleanup=True)
dot.view()
# Out:
# Warning: Orthogonal edges do not currently handle edge labels. Try using xlabels.
# Warning: Orthogonal edges do not currently handle edge labels. Try using xlabels.
# 'dfs_transaction_graph.pdf'

# %%
# Step 1: Retrieve Layer 1 records where "Money Transfer" occurs
layer1_records = df[(df['layer'] == 1) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
layer1_nodes = layer1_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date', 'amount', 'remarks']]

# Create a directed graph
G = nx.DiGraph()

# Add Layer 1 nodes (from_account_no as nodes, with details as attributes)
for _, row in layer1_nodes.iterrows():
    G.add_node(row['from_account_no'], 
               to_account=row['to_account_no'], 
               transaction_id=row['transaction_id'], 
               transaction_date=row['transaction_date'], 
               amount= format_amount_indian(row['amount']), 
               remarks=row['remarks'])

# Step 2: Retrieve Layer 2 records where "Money Transfer" occurs
layer2_records = df[(df['layer'] == 2) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
layer2_nodes = layer2_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date', 'amount', 'remarks']]

# Add Layer 2 nodes and connect edges based on "to_account_no" in Layer 2 matching "from_account_no" in Layer 1
for _, row in layer2_nodes.iterrows():
    # Find matching Layer 1 nodes where to_account_no equals from_account_no in Layer 2
    matching_layer1_nodes = layer1_nodes[layer1_nodes['from_account_no'] == row['to_account_no']]
    
    for _, layer1_row in matching_layer1_nodes.iterrows():
        # Add Layer 2 node
        G.add_node(row['from_account_no'], 
                   to_account=row['to_account_no'], 
                   transaction_id=row['transaction_id'], 
                   transaction_date=row['transaction_date'], 
                   amount= format_amount_indian(row['amount']),
                   remarks=row['remarks'])
        
        # Add edges from Layer 1's from_account_no to Layer 2's from_account_no
        G.add_edge(layer1_row['from_account_no'], row['from_account_no'])

# Step 3: Retrieve Layer 3 records where "Money Transfer" occurs
layer3_records = df[(df['layer'] == 3) & (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
layer3_nodes = layer3_records[['from_account_no', 'to_account_no', 'transaction_id', 'transaction_date', 'amount', 'remarks']]

# Add Layer 3 nodes and connect edges based on "to_account_no" in Layer 3 matching "from_account_no" in Layer 2
for _, row in layer3_nodes.iterrows():
    # Find matching Layer 1 nodes where to_account_no equals from_account_no in Layer 2
    matching_layer2_nodes = layer2_nodes[layer2_nodes['from_account_no'] == row['to_account_no']]
    
    for _, layer2_row in matching_layer2_nodes.iterrows():
        # Add Layer 3 node
        G.add_node(row['from_account_no'], 
                to_account=row['to_account_no'], 
                transaction_id=row['transaction_id'], 
                transaction_date=row['transaction_date'], 
                amount= format_amount_indian(row['amount']),
                remarks=row['remarks'])
        
        # Add edges from Layer 1's from_account_no to Layer 2's from_account_no
        G.add_edge(layer2_row['from_account_no'], row['from_account_no'])

# %%
# Create a directed graph
G = nx.DiGraph()

# Iterate over the layers from 1 to 7
for layer in range(1, 8):
    # Retrieve records for the current layer where "Money Transfer" occurs
    layer_records = df[(df['layer'] == layer) & 
                       (df['action_taken_by_bank_wallet_pgpa_merchant_insurance'].str.contains('Money Transfer'))]
    
    # Extract relevant columns
    layer_nodes = layer_records[['from_account_no', 'to_account_no', 'transaction_id', 
                                  'transaction_date', 'amount', 'remarks']]
    
    # Process each record in the current layer
    for _, row in layer_nodes.iterrows():
        # Add the current layer node with 'layer' attribute
        G.add_node(row['from_account_no'], 
                   layer=layer,  # Add 'layer' attribute
                   to_account=row['to_account_no'], 
                   transaction_id=row['transaction_id'], 
                   transaction_date=row['transaction_date'], 
                   amount=format_amount_indian(row['amount']), 
                   remarks=row['remarks'])
        
        # If this is not the first layer, connect edges to the previous layer's nodes
        if layer > 1:
            # Get nodes from the previous layer
            prev_layer_nodes = df[(df['layer'] == layer - 1) & 
                                  (df['to_account_no'] == row['from_account_no'])]
            
            for _, prev_row in prev_layer_nodes.iterrows():
                # Add edge from previous layer's from_account_no to current layer's from_account_no
                G.add_edge(prev_row['from_account_no'], row['from_account_no'])

# %%
# Create elements for Dash Cytoscape
cyto_elements = []

# Custom positions to create an L-shape for edges
layer_xs = [100, 300, 600, 900, 1200, 1500, 1800, 2100]  # x-coordinates for each layer
y_increment = 100
current_ys = [100] * 8  # y-coordinates for each layer

# Create a dictionary to store node positions for each layer
layer_node_positions = {}

# Iterate over the layers from 0 to 7
for layer in range(8):
    layer_node_positions[layer] = {}  # Initialize node positions for the current layer
    
    # Iterate over the nodes in the current layer
    for node in G.nodes(data=True):
        if node[1]['layer'] == layer:  # Node belongs to the current layer
            # Define the content string with details in multi-line format
            content = (f"{node[0]}\n"
                       f"To: {node[1]['to_account']}\n"
                       f"Transaction ID: {node[1]['transaction_id']}\n"
                       f"Date: {node[1]['transaction_date']}\n"
                       f"Amount: {node[1]['amount']}\n"
                       f"Remarks: {node[1]['remarks']}")
            
            # Add the node to cyto_elements
            cyto_elements.append({
                'data': {'id': node[0], 'label': content},  # Display node content
                'position': {'x': layer_xs[layer], 'y': current_ys[layer]}  # Positioning for the current layer
            })
            layer_node_positions[layer][node[0]] = (layer_xs[layer], current_ys[layer])  # Track node position for edges
            current_ys[layer] += y_increment  # Increment y-coordinate for the next node in the same layer

# Add edges between nodes in adjacent layers
for edge in G.edges():
    source_layer = next((layer for layer, nodes in enumerate(G.nodes(data=True)) if edge[0] in [node[0] for node in nodes]), None)
    target_layer = next((layer for layer, nodes in enumerate(G.nodes(data=True)) if edge[1] in [node[0] for node in nodes]), None)
    
    if source_layer is not None and target_layer is not None:
        cyto_elements.append({
            'data': {'source': edge[0], 'target': edge[1]},
            'style': {'line-color': '#ff0000', 'width': 2, 'target-arrow-shape': 'triangle', 'arrow-color': '#0074D9'}
        })

# %%
# Create elements for Dash Cytoscape
cyto_elements = []

# Custom positions to create an L-shape for edges
layer1_x = 100
layer2_x = 300  # Shift layer 2 nodes further right
layer3_x = 600
y_increment = 100
current_y = 100

# Add nodes for Layer 1
layer1_node_positions = {}  # Keep track of node positions
for i, node in enumerate(G.nodes(data=True)):
    if node[1]['to_account'] in layer1_nodes['to_account_no'].values:  # Layer 1 nodes
        # Define the content string with details in multi-line format
        content = (f"{node[0]}\n"
                   f"To: {node[1]['to_account']}\n"
                   f"Transaction ID: {node[1]['transaction_id']}\n"
                   f"Date: {node[1]['transaction_date']}\n"
                   f"Amount: {node[1]['amount']}\n"
                   f"Remarks: {node[1]['remarks']}")
         
        cyto_elements.append({
            'data': {'id': node[0], 'label': content},  # Display node content
            'position': {'x': layer1_x, 'y': current_y}  # Positioning for layer 1
        })
        layer1_node_positions[node[0]] = (layer1_x, current_y)  # Track Layer 1 node position for edges
        current_y += y_increment

# Reset y position for Layer 2
current_y = 100

# Add nodes for Layer 2 and edges
layer2_node_positions = {}  # Keep track of layer 2 node positions
for node in G.nodes(data=True):
    if node[1]['to_account'] not in layer1_nodes['to_account_no'].values:  # Layer 2 nodes
        # Define the content string with details in multi-line format
        content = (f"{node[0]}\n"
                   f"To: {node[1]['to_account']}\n"
                   f"Transaction ID: {node[1]['transaction_id']}\n"
                   f"Date: {node[1]['transaction_date']}\n"
                   f"Amount: {node[1]['amount']}\n"
                   f"Remarks: {node[1]['remarks']}")
        
        cyto_elements.append({
            'data': {'id': node[0], 'label': content},  # Display node content
            'position': {'x': layer2_x, 'y': current_y}  # Positioning for layer 2
        })
        layer2_node_positions[node[0]] = (layer2_x, current_y)  # Track Layer 2 node position for edges
        current_y += y_increment

current_y = 100
# Add nodes for Layer 2 and edges
layer3_node_positions = {}  # Keep track of layer 2 node positions
for node in G.nodes(data=True):
    if node[1]['to_account'] not in layer2_nodes['to_account_no'].values:  # Layer 2 nodes
        # Define the content string with details in multi-line format
        content = (f"{node[0]}\n"
                   f"To: {node[1]['to_account']}\n"
                   f"Transaction ID: {node[1]['transaction_id']}\n"
                   f"Date: {node[1]['transaction_date']}\n"
                   f"Amount: {node[1]['amount']}\n"
                   f"Remarks: {node[1]['remarks']}")
        
        cyto_elements.append({
            'data': {'id': node[0], 'label': content},  # Display node content
            'position': {'x': layer3_x, 'y': current_y}  # Positioning for layer 2
        })
        layer3_node_positions[node[0]] = (layer3_x, current_y)  # Track Layer 2 node position for edges
        current_y += y_increment

# Add edges between Layer 1 and Layer 2
for edge in G.edges():
    cyto_elements.append({
        'data': {'source': edge[0], 'target': edge[1]},
        'style': {'line-color': '#ff0000', 'width': 2, 'target-arrow-shape': 'triangle', 'arrow-color': '#0074D9'}
    })

# Initialize Dash app
app = JupyterDash(__name__)

app.layout = html.Div([
    cyto.Cytoscape(
        id='cytoscape-network',
        elements=cyto_elements,
        style={'width': '100%', 'height': '800px'},
        layout={'name': 'breadthfirst'},  # Use preset layout to keep positions defined
        stylesheet=[
            {'selector': 'node', 'style': {'content': 'data(label)', 'shape': 'rectangle', 'background-color': '#00ffD9', 'text-wrap': 'wrap', 'font-size': '12px', 'text-valign': 'bottom', 'text-halign': 'right'}},
            {'selector': 'edge', 'style': {'line-color': '#ff0000', 'curve-style': 'straight', 'target-arrow-shape': 'triangle'}}  # Straight edge styling
        ]
    )
])

if __name__ == '__main__':
    app.run_server(debug=True, port=4282)
